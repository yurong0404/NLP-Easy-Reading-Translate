# %%
import nltk
from nltk import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from gensim.test.utils import get_tmpfile
from gensim.models import KeyedVectors
import os
import requests
import json
from bs4 import BeautifulSoup
from collections import defaultdict
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/YuRong/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# # Function definition

# %%
NGRAM_API_URI = "https://{0}.linggle.com/query/"
class Linggle:
    def __init__(self, ver='www'):
        self.ver = ver

    def __getitem__(self, query):
        return self.search(query)

    def search(self, query):
        query = query.replace('/', '@')
        req = requests.get(NGRAM_API_URI.format(self.ver) + query)
        results = req.json()
        return results.get('ngrams', [])
    
    
def extract(soup):
    word_list = []
    for term in soup.select('.pt-list-terms'):
        count = 0    
        for item in term.select('.pt-list-terms__item'):
            if item.select('.pt-list-rating__indicator--high'):
                for title in item.select('.pt-thesaurus-card__term-title'):
                    if title.select_one('.link--term'):
                        if count == 3:
                            break
                        else:
                            count += 1
                            word_list.append(title.select_one('.link--term').text)
    return word_list

def crawl(url):
    headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 6.0; WOW64; rv:24.0) Gecko/20100101 Firefox/24.0' }
    source_code = requests.get(url , headers=headers).content
    soup = BeautifulSoup(source_code, 'html.parser')
    return extract(soup)
    
def synonymsPT(word):
    r = 'https://www.powerthesaurus.org/'+ word +'/synonyms'
    synonymsList = crawl(r)
    max_count = 0
    max_word = word
    for synonym in synonymsList:
        count = sum([row[1] for row in ling[word+" _"]][:10]) + sum([row[1] for row in ling["_ "+word]][:10])
        s_count = sum([row[1] for row in ling[synonym+" _"]][:10]) + sum([row[1] for row in ling["_ "+synonym]][:10])
        if s_count > (2*count) and s_count > 800000:
            max_count = s_count
            max_word = synonym
    return max_word

def crawlCNN(url):
    headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 6.0; WOW64; rv:24.0) Gecko/20100101 Firefox/24.0' }
    source_code = requests.get(url , headers=headers).content
    soup = BeautifulSoup(source_code, 'html.parser')
    
    paragraph = ""
    for big_block in soup.select('.zn-body__paragraph'):
        paragraph += big_block.text + '\n'
    
    return paragraph

def modifiedParagraph(origin, diffWord):
    origin = origin.split(' ')
    for word in diffWord:
        origin[word[0]] = origin[word[0]].replace(word[2], word[4])
    modified = ' '.join(origin)
    return modified, [x[4] for x in diffWord]

# %%
print(modifiedParagraph(origin, diffWord))
# Out:
# ('Hong Kong (CNN)Hong Kong\'s government has blinked. The city\'s leader Carrie Lam announced Saturday she was suspending a controversial surrender bill after mass protests and sustained opposition from multiple sectors of society. \nWhile she fell short of fully withdrawing the bill -- or resigning -- as some protesters had demand, the move is nevertheless a major win for the hundreds of thousands who took to the streets on June 9, as well as the tens of thousands of mostly young protesters who shut down parts of the city on Wednesday and prevented legislation from beginning a second reading. \nProtest organizers are calling for another mass rally on Sunday in a bid to keep the pressure on the government. Protesters will wear black and demand the bill be completely withdrawn and Lam step down. \nPro-democracy figures claim the bill\'s reintroduction would lead to the erosion of civil rights in Hong Kong, including freedom of speech and rule of law, and could see residents sent to China to face prosecution in a country with an opaque legal system.\nBeijing has yet to officially react to Lam\'s announcement that she was suspending the bill, though the Chief Executive has emphasized that she had the central government\'s support. \nFrom all available accounts, it appears that the bill was an initiative of Lam\'s government -- as she has claimed all along -- rather than an order from on high. \nLam and her ministers appear to have seen in a gruesome Taiwan murder case a way to win an easy public relations victory by extraditing a wanted killer to face justice, and a way to close shortcomings and extend the central government\'s powers to go after fugitives, especially former Chinese officials, in Hong Kong. \nThey do not, however, seem to have expected the overwhelmingly negative response to the bill and the deep, widespread dislike for the Chinese legal system. Pro-democracy activists, NGOs and business groups came together in calling for the bill\'s withdrawal, and it also served to unify the previously broken political opposition. \nProtests this month -- with the June 9 march the largest since Hong Kong was handed over to Chinese control, and Wednesday\'s protests among some of the most violent scenes ever seen in the city -- left Lam unwilling to push forward with a bill so clearly unpopular and potentially dangerous. \nHowever, while the climbdown is certainly embarrassing to both the Hong Kong and Beijing governments, it only maintains the status quo, as did a mass movement against an anti-sedition law in 2003, previously the largest protests Hong Kong had seen under Chinese rule. \nHong Kong residents have proven more willing to come to the streets to fight back against a loss of political freedoms than to push for extra ones, and both the local and central governments appear to have a greater degree of flexibility or patience on these issues as well. \nThe situation in 2014, when demands for the direct election of the chief executive spiraled into the Umbrella Movement, was very different. Those protests did not attract such a broad path of society, and they were also greeted with a much more forceful reaction by Beijing, and a subsequent protests and numerous prosecutions and disqualifications of legislation. \nDoes the bill have a future?\nWhile Lam emphasized that the bill has been suspended rather than completely withdrawn, it is likely that the effect will be the same, at least in the near term. \nAs opposition to the bill grew, Taipei said it would not request the murder suspect\'s surrender from Hong Kong, as it said the bill would put Taiwanese citizens in danger. With this off the table, Lam admitted there was "less urgency to pass the bill this year." \nGoing forward, she said she wanted to focus on "economic and support" issues, particularly those such as housing, a consistent major issue in Hong Kong, particularly for young people of the sort out protest Wednesday. \nThat language is similar to what she has u ...

# %%
# Out:
# [(19, 'NN', 'extradition', 'extradition', 'surrender', 'PT website'),
#  (92, 'NNS', 'lawmakers', 'lawmaker', 'legislation', 'word embedding'),
#  (269, 'NNS', 'loopholes', 'loophole', 'shortcomings', 'PT website'),
#  (306, 'NN', 'distrust', 'distrust', 'dislike', 'word embedding'),
#  (334, 'VBN', 'fractured', 'fracture', 'broken', 'word embedding'),
#  (510, 'NN', 'swath', 'swath', 'path', 'PT website'),
#  (529, 'NN', 'crackdown', 'crackdown', 'protests', 'word embedding'),
#  (536, 'NNS', 'lawmakers', 'lawmaker', 'legislation', 'word embedding'),
#  (586, 'NN', 'extradition', 'extradition', 'surrender', 'PT website'),
#  (629, 'NN', 'livelihood', 'livelihood', 'support', 'PT website'),
#  (651, 'NN', 'protesting', 'protesting', 'protest', 'word embedding'),
#  (681, 'VBN', 'shelved', 'shelve', 'filed', 'PT website'),
#  (714, 'NN', 'extradition', 'extradition', 'surrender', 'PT website'),
#  (736, 'VB', 'reintroduce', 'reintroduce', 'restore', 'PT website'),
#  (755, 'VBN', 'reinvigorated', 'reinvigorate', 'fresh', 'PT website'),
#  (769, 'VB', 'wrest', 'wrest', 'extract', 'PT website'),
#  (771, 'NN', 'veto', 'veto', 'override', 'word embedding'),
#  (778, 'NNS', 'lawmakers', 'lawmaker', 'legislation', 'word embedding')]

# %%
paragraph
# Out:
# ['Hong',
#  'Kong',
#  '(CNN)Hong',
#  "Kong's",
#  'government',
#  'has',
#  'blinked.',
#  'The',
#  "city's",
#  'leader',
#  'Carrie',
#  'Lam',
#  'announced',
#  'Saturday',
#  'she',
#  'was',
#  'suspending',
#  'a',
#  'controversial',
#  'extradition',
#  'bill',
#  'after',
#  'mass',
#  'protests',
#  'and',
#  'sustained',
#  'opposition',
#  'from',
#  'multiple',
#  'sectors',
#  'of',
#  'society.',
#  '\nWhile',
#  'she',
#  'fell',
#  'short',
#  'of',
#  'fully',
#  'withdrawing',
#  'the',
#  'bill',
#  '--',
#  'or',
#  'resigning',
#  '--',
#  'as',
#  'some',
#  'protesters',
#  'had',
#  'demand,',
#  'the',
#  'move',
#  'is',
#  'nevertheless',
#  'a',
#  'major',
#  'win',
#  'for',
#  'the',
#  'hundreds',
#  'of',
#  'thousands',
#  'who',
#  'took',
#  'to',
#  'the',
#  'streets',
#  'on',
#  'June',
#  '9,',
#  'as',
#  'well',
#  'as',
#  'the',
#  'tens',
#  'of',
#  'thousands',
#  'of',
#  'mostly',
#  'young',
#  'protesters',
#  'who',
#  'shut',
#  'down',
#  'parts',
#  'of',
#  'the',
#  'city',
#  'on',
#  'Wednesday',
#  'and',
#  'prevented',
#  'lawmakers',
#  'from',
#  'beginning',
#  'a',
#  'second',
#  'reading.',
#  '\nProtest',
#  'organizers',
#  'are',
#  'calling',
#  'for',
#  'another',
#  'mass',
#  'rally',
#  'on',
#  'Sunday',
#  'in',
#  'a',
#  'bid',
#  'to',
#  'keep',
#  'the',
#  'pressure',
#  'on',
#  'the',
#  'government.',
#  'Protesters',
#  'will',
#  'wear',
#  'black',
#  'and',
#  'demand',
#  'the',
#  'bill',
#  'be',
#  'completely',
#  'withdrawn',
#  'and',
#  'Lam',
#  'step',
#  'down.',
#  '\nPro-democracy',
#  'figures',
#  'claim',
#  'the',
#  "bill's",
#  'reintroduction',
#  'would',
#  'lead',
#  'to',
#  'the',
#  'erosion',
#  'of',
#  'civil',
#  'rights',
#  'in',
#  'Hong',
#  'Kong,',
#  'including',
#  'freedom',
#  'of',
#  'speech',
#  'and',
#  'rule',
#  'of',
#  'law,',
#  'and',
#  'could',
#  'see',
#  'residents',
#  'sent',
#  'to',
#  'China',
#  'to',
#  'face',
#  'prosecution',
#  'in',
#  'a',
#  'country',
#  'with',
#  'an',
#  'opaque',
#  'legal',
#  'system.\nBeijing',
#  'has',
#  'yet',
#  'to',
#  'officially',
#  'react',
#  'to',
#  "Lam's",
#  'announcement',
#  'that',
#  'she',
#  'was',
#  'suspending',
#  'the',
#  'bill,',
#  'though',
#  'the',
#  'Chief',
#  'Executive',
#  'has',
#  'emphasized',
#  'that',
#  'she',
#  'had',
#  'the',
#  'central',
#  "government's",
#  'support.',
#  '\nFrom',
#  'all',
#  'available',
#  'accounts,',
#  'it',
#  'appears',
#  'that',
#  'the',
#  'bill',
#  'was',
#  'an',
#  'initiative',
#  'of',
#  "Lam's",
#  'government',
#  '--',
#  'as',
#  'she',
#  'has',
#  'claimed',
#  'all',
#  'along',
#  '--',
#  'rather',
#  'than',
#  'an',
#  'order',
#  'from',
#  'on',
#  'high.',
#  '\nLam',
#  'and',
#  'her',
#  'ministers',
#  'appear',
#  'to',
#  'have',
#  'seen',
#  'in',
#  'a',
#  'gruesome',
#  'Taiwan',
#  'murder',
#  'case',
#  'a',
#  'way',
#  'to',
#  'win',
#  'an',
#  'easy',
#  'public',
#  'relations',
#  'victory',
#  'by',
#  'extraditing',
#  'a',
#  'wanted',
#  'killer',
#  'to',
#  'face',
#  'justice,',
#  'and',
#  'a',
#  'way',
#  'to',
#  'close',
#  'loopholes',
#  'and',
#  'extend',
#  'the',
#  'central',
#  "government's",
#  'powers',
#  'to',
#  'go',
#  'after',
#  'fugitives,',
#  'especially',
#  'former',
#  'Chinese',
#  'officials,',
#  'in',
#  'Hong',
#  'Kong.',
#  '\nThey',
#  'do',
#  'not,',
#  'however,',
#  'seem',
#  'to',
#  'have',
#  'expected',
#  'the',
#  'overwhelmingly',
#  'negative',
#  'response',
#  'to',
#  'the',
#  'bill',
#  'and',
#  'the',
#  'deep,',
#  'widespread',
#  'distrust',
#  'for',
#  'the',
#  'Chinese',
#  'legal',
#  'system.',
#  'Pro-democracy',
#  'activists,',
#  'NGOs',
#  'and',
#  'business',
#  'groups',
#  'came',
#  'together',
#  'in',
#  'calling',
#  'for',
#  'the',
#  "bill's",
#  'withdrawal,',
#  'and',
#  'it',
#  'also',
#  'served',
#  'to',
#  'unify',
#  'the',
#  'previously',
#  'fractured',
#  'political',
#  'opposition.',
#  '\nProtests',
#  'this',
#  'month',
#  '--',
#  'with',
#  'the',
#  'June',
#  '9',
#  'march',
#  'the',
#  'largest',
#  'since',
#  'Hong',
#  'Kong',
#  'was',
#  'handed',
#  'over',
#  'to',
#  'Chinese',
#  'control,',
#  'and',
#  "Wednesday's",
#  'protests',
#  'among',
#  'some',
#  'of',
#  'the',
#  'most',
#  'violent',
#  'scenes',
#  'ever',
#  'seen',
#  'in',
#  'the',
#  'city',
#  '--',
#  'left',
#  'Lam',
#  'unwilling',
#  'to',
#  'push',
#  'forward',
#  'with',
#  'a',
#  'bill',
#  'so',
#  'clearly',
#  'unpopular',
#  'and',
#  'potentially',
#  'dangerous.',
#  '\nHowever,',
#  'while',
#  'the',
#  'climbdown',
#  'is',
#  'certainly',
#  'embarrassing',
#  'to',
#  'both',
#  'the',
#  'Hong',
#  'Kong',
#  'and',
#  'Beijing',
#  'governments,',
#  'it',
#  'only',
#  'maintains',
#  'the',
#  'status',
#  'quo,',
#  'as',
#  'did',
#  'a',
#  'mass',
#  'movement',
#  'against',
#  'an',
#  'anti-sedition',
#  'law',
#  'in',
#  '2003,',
#  'previously',
#  'the',
#  'largest',
#  'protests',
#  'Hong',
#  'Kong',
#  'had',
#  'seen',
#  'under',
#  'Chinese',
#  'rule.',
#  '\nHong',
#  'Kong',
#  'residents',
#  'have',
#  'proven',
#  'more',
#  'willing',
#  'to',
#  'come',
#  'to',
#  'the',
#  'streets',
#  'to',
#  'fight',
#  'back',
#  'against',
#  'a',
#  'loss',
#  'of',
#  'political',
#  'freedoms',
#  'than',
#  'to',
#  'push',
#  'for',
#  'extra',
#  'ones,',
#  'and',
#  'both',
#  'the',
#  'local',
#  'and',
#  'central',
#  'governments',
#  'appear',
#  'to',
#  'have',
#  'a',
#  'greater',
#  'degree',
#  'of',
#  'flexibility',
#  'or',
#  'patience',
#  'on',
#  'these',
#  'issues',
#  'as',
#  'well.',
#  '\nThe',
#  'situation',
#  'in',
#  '2014,',
#  'when',
#  'demands',
#  'for',
#  'the',
#  'direct',
#  'election',
#  'of',
#  'the',
#  'chief',
#  'executive',
#  'spiraled',
#  'into',
#  'the',
#  'Umbrella',
#  'Movement,',
#  'was',
#  'very',
#  'different.',
#  'Those',
#  'protests',
#  'did',
#  'not',
#  'attract',
#  'such',
#  'a',
#  'broad',
#  'swath',
#  'of',
#  'society,',
#  'and',
#  'they',
#  'were',
#  'also',
#  'greeted',
#  'with',
#  'a',
#  'much',
#  'more',
#  'forceful',
#  'reaction',
#  'by',
#  'Beijing,',
#  'and',
#  'a',
#  'subsequent',
#  'crackdown',
#  'and',
#  'numerous',
#  'prosecutions',
#  'and',
#  'disqualifications',
#  'of',
#  'lawmakers.',
#  '\nDoes',
#  'the',
#  'bill',
#  'have',
#  'a',
#  'future?\nWhile',
#  'Lam',
#  'emphasized',
#  'that',
#  'the',
#  'bill',
#  'has',
#  'been',
#  'suspended',
#  'rather',
#  'than',
#  'completely',
#  'withdrawn,',
#  'it',
#  'is',
#  'likely',
#  'that',
#  'the',
#  'effect',
#  'will',
#  'be',
#  'the',
#  'same,',
#  'at',
#  'least',
#  'in',
#  'the',
#  'near',
#  'term.',
#  '\nAs',
#  'opposition',
#  'to',
#  'the',
#  'bill',
#  'grew,',
#  'Taipei',
#  'said',
#  'it',
#  'would',
#  'not',
#  'request',
#  'the',
#  'murder',
#  "suspect's",
#  'extradition',
#  'from',
#  'Hong',
#  'Kong,',
#  'as',
#  'it',
#  'said',
#  'the',
#  'bill',
#  'would',
#  'put',
#  'Taiwanese',
#  'citizens',
#  'in',
#  'danger.',
#  'With',
#  'this',
#  'off',
#  'the',
#  'table,',
#  'Lam',
#  'admitted',
#  'there',
#  'was',
#  '"less',
#  'urgency',
#  'to',
#  'pass',
#  'the',
#  'bill',
#  'this',
#  'year."',
#  '\nGoing',
#  'forward,',
#  'she',
#  'said',
#  'she',
#  'wanted',
#  'to',
#  'focus',
#  'on',
#  '"economic',
#  'and',
#  'livelihood"',
#  'issues,',
#  'particularly',
#  'those',
#  'such',
#  'as',
#  'housing,',
#  'a',
#  'consistent',
#  'major',
#  'issue',
#  'in',
#  'Hong',
#  'Kong,',
#  'particularly',
#  'for',
#  'young',
#  'people',
#  'of',
#  'the',
#  'sort',
#  'out',
#  'protesting',
#  'Wednesday.',
#  '\nThat',
#  'language',
#  'is',
#  'similar',
#  'to',
#  'what',
#  'she',
#  'has',
#  'used',
#  'in',
#  'the',
#  'past',
#  'when',
#  'discussing',
#  'whether',
#  'her',
#  'government',
#  'would',
#  'seek',
#  'to',
#  'introduce',
#  'Article',
#  '23,',
#  'the',
#  'anti-sedition',
#  'law',
#  'which',
#  'was',
#  'shelved',
#  'after',
#  'mass',
#  'protests',
#  'against',
#  'it',
#  'in',
#  '2003.',
#  'Lam',
#  'has',
#  'said',
#  'she',
#  'would',
#  'only',
#  'do',
#  'so',
#  'were',
#  'the',
#  'conditions',
#  'in',
#  'society',
#  'correct,',
#  'and',
#  'on',
#  'Saturday',
#  'she',
#  'said',
#  'she',
#  'regretted',
#  'that',
#  'controversies',
#  'over',
#  'the',
#  'extradition',
#  'bill',
#  'had',
#  'spoiled',
#  'the',
#  '"period',
#  'of',
#  'calm"',
#  'Hong',
#  'Kong',
#  'had',
#  'enjoyed',
#  'since',
#  'she',
#  'took',
#  'office',
#  'in',
#  '2017.',
#  '\nWhile',
#  'the',
#  'government',
#  'could',
#  'reintroduce',
#  'the',
#  'bill',
#  'next',
#  'year,',
#  'it',
#  'is',
#  'unlikely',
#  'as',
#  '2020',
#  'is',
#  'an',
#  'election',
#  'year',
#  'for',
#  'the',
#  'legislative',
#  'council.\nThe',
#  'newly',
#  'reinvigorated',
#  'and',
#  'unified',
#  'pro-democratic',
#  'camp',
#  'will',
#  'be',
#  'targeting',
#  'marginal',
#  'seats',
#  'in',
#  'an',
#  'attempt',
#  'to',
#  'wrest',
#  'back',
#  'veto',
#  'power',
#  'in',
#  'the',
#  'legislature,',
#  'and',
#  'pro-Beijing',
#  'lawmakers',
#  'have',
#  'already',
#  'warned',
#  'that',
#  'the',
#  'controversies',
#  'over',
#  'the',
#  'bill',
#  'could',
#  'cost',
#  'them',
#  'seats.',
#  '\nSo',
#  'though',
#  'some',
#  'protesters',
#  'and',
#  'opposition',
#  'figures',
#  'may',
#  'complain',
#  'that',
#  'Lam',
#  'has',
#  'only',
#  'suspended',
#  'rather',
#  'than',
#  'withdrawn',
#  'the',
#  'bill,',
#  'the',
#  'effect',
#  'may',
#  'end',
#  'up',
#  'being',
#  'the',
#  'same.',
#  '\n\n']

# %%
print(origin)
# Out:
# Hong Kong (CNN)Hong Kong's government has blinked. The city's leader Carrie Lam announced Saturday she was suspending a controversial extradition bill after mass protests and sustained opposition from multiple sectors of society.
# While she fell short of fully withdrawing the bill -- or resigning -- as some protesters had demand, the move is nevertheless a major win for the hundreds of thousands who took to the streets on June 9, as well as the tens of thousands of mostly young protesters who shut down parts of the city on Wednesday and prevented lawmakers from beginning a second reading.
# Protest organizers are calling for another mass rally on Sunday in a bid to keep the pressure on the government. Protesters will wear black and demand the bill be completely withdrawn and Lam step down.
# Pro-democracy figures claim the bill's reintroduction would lead to the erosion of civil rights in Hong Kong, including freedom of speech and rule of law, and could see residents sent to China to face prosecution in a country with an opaque legal system.
# Beijing has yet to officially react to Lam's announcement that she was suspending the bill, though the Chief Executive has emphasized that she had the central government's support.
# From all available accounts, it appears that the bill was an initiative of Lam's government -- as she has claimed all along -- rather than an order from on high.
# Lam and her ministers appear to have seen in a gruesome Taiwan murder case a way to win an easy public relations victory by extraditing a wanted killer to face justice, and a way to close loopholes and extend the central government's powers to go after fugitives, especially former Chinese officials, in Hong Kong.
# They do not, however, seem to have expected the overwhelmingly negative response to the bill and the deep, widespread distrust for the Chinese legal system. Pro-democracy activists, NGOs and business groups came together in calling for the bill's withdrawal, and it also served to unify the previously fractured political opposition.
# Protests this month -- with the June 9 march the largest since Hong Kong was handed over to Chinese control, and Wednesday's protests among some of the most violent scenes ever seen in the city -- left Lam unwilling to push forward with a bill so clearly unpopular and potentially dangerous.
# However, while the climbdown is certainly embarrassing to both the Hong Kong and Beijing governments, it only maintains the status quo, as did a mass movement against an anti-sedition law in 2003, previously the largest protests Hong Kong had seen under Chinese rule.
# Hong Kong residents have proven more willing to come to the streets to fight back against a loss of political freedoms than to push for extra ones, and both the local and central governments appear to have a greater degree of flexibility or patience on these issues as well.
# The situation in 2014, when demands for the direct election of the chief executive spiraled into the Umbrella Movement, was very different. Those protests did not attract such a broad swath of society, and they were also greeted with a much more forceful reaction by Beijing, and a subsequent crackdown and numerous prosecutions and disqualifications of lawmakers.
# Does the bill have a future?
# While Lam emphasized that the bill has been suspended rather than completely withdrawn, it is likely that the effect will be the same, at least in the near term.
# As opposition to the bill grew, Taipei said it would not request the murder suspect's extradition from Hong Kong, as it said the bill would put Taiwanese citizens in danger. With this off the table, Lam admitted there was "less urgency to pass the bill this year."
# Going forward, she said she wanted to focus on "economic and livelihood" issues, particularly those such as housing, a consistent major issue in Hong Kong, particularly for young people of the sort out protesting Wednesday.
# That language is similar to what she has used in the past when discussing whether her government would seek to introduce Article 23, the anti-sedition law which was shelved after mass protests against it in 2003. Lam has said she would only do so were the conditions in society correct, and on Saturday she said she regretted that controversies over the extradition bill had spoiled the "period of calm" Hong Kong had enjoyed since she took office in 2017.
# While the government could reintroduce the bill next year, it is unlikely as 2020 is an election year for the legislative council.
# The newly reinvigorated and unified pro-democratic camp will be targeting marginal seats in an attempt to wrest back veto power in the legislature, and pro-Beijing lawmakers have already warned that the controversies over the bill could cost them seats.
# So though some protesters and opposition figures may complain that Lam has only suspended rather than withdrawn the bill, the effect may end up being the same.

# %%
word_token
# Out:
# {0: ['Hong'],
#  1: ['Kong'],
#  2: ['(', 'CNN', ')', 'Hong'],
#  3: ['Kong', "'s"],
#  4: ['government'],
#  5: ['has'],
#  6: ['blinked', '.'],
#  7: ['The'],
#  8: ['city', "'s"],
#  9: ['leader'],
#  10: ['Carrie'],
#  11: ['Lam'],
#  12: ['announced'],
#  13: ['Saturday'],
#  14: ['she'],
#  15: ['was'],
#  16: ['suspending'],
#  17: ['a'],
#  18: ['controversial'],
#  19: ['extradition'],
#  20: ['bill'],
#  21: ['after'],
#  22: ['mass'],
#  23: ['protests'],
#  24: ['and'],
#  25: ['sustained'],
#  26: ['opposition'],
#  27: ['from'],
#  28: ['multiple'],
#  29: ['sectors'],
#  30: ['of'],
#  31: ['society', '.'],
#  32: ['While'],
#  33: ['she'],
#  34: ['fell'],
#  35: ['short'],
#  36: ['of'],
#  37: ['fully'],
#  38: ['withdrawing'],
#  39: ['the'],
#  40: ['bill'],
#  41: ['--'],
#  42: ['or'],
#  43: ['resigning'],
#  44: ['--'],
#  45: ['as'],
#  46: ['some'],
#  47: ['protesters'],
#  48: ['had'],
#  49: ['demand', ','],
#  50: ['the'],
#  51: ['move'],
#  52: ['is'],
#  53: ['nevertheless'],
#  54: ['a'],
#  55: ['major'],
#  56: ['win'],
#  57: ['for'],
#  58: ['the'],
#  59: ['hundreds'],
#  60: ['of'],
#  61: ['thousands'],
#  62: ['who'],
#  63: ['took'],
#  64: ['to'],
#  65: ['the'],
#  66: ['streets'],
#  67: ['on'],
#  68: ['June'],
#  69: ['9', ','],
#  70: ['as'],
#  71: ['well'],
#  72: ['as'],
#  73: ['the'],
#  74: ['tens'],
#  75: ['of'],
#  76: ['thousands'],
#  77: ['of'],
#  78: ['mostly'],
#  79: ['young'],
#  80: ['protesters'],
#  81: ['who'],
#  82: ['shut'],
#  83: ['down'],
#  84: ['parts'],
#  85: ['of'],
#  86: ['the'],
#  87: ['city'],
#  88: ['on'],
#  89: ['Wednesday'],
#  90: ['and'],
#  91: ['prevented'],
#  92: ['lawmakers'],
#  93: ['from'],
#  94: ['beginning'],
#  95: ['a'],
#  96: ['second'],
#  97: ['reading', '.'],
#  98: ['Protest'],
#  99: ['organizers'],
#  100: ['are'],
#  101: ['calling'],
#  102: ['for'],
#  103: ['another'],
#  104: ['mass'],
#  105: ['rally'],
#  106: ['on'],
#  107: ['Sunday'],
#  108: ['in'],
#  109: ['a'],
#  110: ['bid'],
#  111: ['to'],
#  112: ['keep'],
#  113: ['the'],
#  114: ['pressure'],
#  115: ['on'],
#  116: ['the'],
#  117: ['government', '.'],
#  118: ['Protesters'],
#  119: ['will'],
#  120: ['wear'],
#  121: ['black'],
#  122: ['and'],
#  123: ['demand'],
#  124: ['the'],
#  125: ['bill'],
#  126: ['be'],
#  127: ['completely'],
#  128: ['withdrawn'],
#  129: ['and'],
#  130: ['Lam'],
#  131: ['step'],
#  132: ['down', '.'],
#  133: ['Pro-democracy'],
#  134: ['figures'],
#  135: ['claim'],
#  136: ['the'],
#  137: ['bill', "'s"],
#  138: ['reintroduction'],
#  139: ['would'],
#  140: ['lead'],
#  141: ['to'],
#  142: ['the'],
#  143: ['erosion'],
#  144: ['of'],
#  145: ['civil'],
#  146: ['rights'],
#  147: ['in'],
#  148: ['Hong'],
#  149: ['Kong', ','],
#  150: ['including'],
#  151: ['freedom'],
#  152: ['of'],
#  153: ['speech'],
#  154: ['and'],
#  155: ['rule'],
#  156: ['of'],
#  157: ['law', ','],
#  158: ['and'],
#  159: ['could'],
#  160: ['see'],
#  161: ['residents'],
#  162: ['sent'],
#  163: ['to'],
#  164: ['China'],
#  165: ['to'],
#  166: ['face'],
#  167: ['prosecution'],
#  168: ['in'],
#  169: ['a'],
#  170: ['country'],
#  171: ['with'],
#  172: ['an'],
#  173: ['opaque'],
#  174: ['legal'],
#  175: ['system', '.', 'Beijing'],
#  176: ['has'],
#  177: ['yet'],
#  178: ['to'],
#  179: ['officially'],
#  180: ['react'],
#  181: ['to'],
#  182: ['Lam', "'s"],
#  183: ['announcement'],
#  184: ['that'],
#  185: ['she'],
#  186: ['was'],
#  187: ['suspending'],
#  188: ['the'],
#  189: ['bill', ','],
#  190: ['though'],
#  191: ['the'],
#  192: ['Chief'],
#  193: ['Executive'],
#  194: ['has'],
#  195: ['emphasized'],
#  196: ['that'],
#  197: ['she'],
#  198: ['had'],
#  199: ['the'],
#  200: ['central'],
#  201: ['government', "'s"],
#  202: ['support', '.'],
#  203: ['From'],
#  204: ['all'],
#  205: ['available'],
#  206: ['accounts', ','],
#  207: ['it'],
#  208: ['appears'],
#  209: ['that'],
#  210: ['the'],
#  211: ['bill'],
#  212: ['was'],
#  213: ['an'],
#  214: ['initiative'],
#  215: ['of'],
#  216: ['Lam', "'s"],
#  217: ['government'],
#  218: ['--'],
#  219: ['as'],
#  220: ['she'],
#  221: ['has'],
#  222: ['claimed'],
#  223: ['all'],
#  224: ['along'],
#  225: ['--'],
#  226: ['rather'],
#  227: ['than'],
#  228: ['an'],
#  229: ['order'],
#  230: ['from'],
#  231: ['on'],
#  232: ['high', '.'],
#  233: ['Lam'],
#  234: ['and'],
#  235: ['her'],
#  236: ['ministers'],
#  237: ['appear'],
#  238: ['to'],
#  239: ['have'],
#  240: ['seen'],
#  241: ['in'],
#  242: ['a'],
#  243: ['gruesome'],
#  244: ['Taiwan'],
#  245: ['murder'],
#  246: ['case'],
#  247: ['a'],
#  248: ['way'],
#  249: ['to'],
#  250: ['win'],
#  251: ['an'],
#  252: ['easy'],
#  253: ['public'],
#  254: ['relations'],
#  255: ['victory'],
#  256: ['by'],
#  257: ['extraditing'],
#  258: ['a'],
#  259: ['wanted'],
#  260: ['killer'],
#  261: ['to'],
#  262: ['face'],
#  263: ['justice', ','],
#  264: ['and'],
#  265: ['a'],
#  266: ['way'],
#  267: ['to'],
#  268: ['close'],
#  269: ['loopholes'],
#  270: ['and'],
#  271: ['extend'],
#  272: ['the'],
#  273: ['central'],
#  274: ['government', "'s"],
#  275: ['powers'],
#  276: ['to'],
#  277: ['go'],
#  278: ['after'],
#  279: ['fugitives', ','],
#  280: ['especially'],
#  281: ['former'],
#  282: ['Chinese'],
#  283: ['officials', ','],
#  284: ['in'],
#  285: ['Hong'],
#  286: ['Kong', '.'],
#  287: ['They'],
#  288: ['do'],
#  289: ['not', ','],
#  290: ['however', ','],
#  291: ['seem'],
#  292: ['to'],
#  293: ['have'],
#  294: ['expected'],
#  295: ['the'],
#  296: ['overwhelmingly'],
#  297: ['negative'],
#  298: ['response'],
#  299: ['to'],
#  300: ['the'],
#  301: ['bill'],
#  302: ['and'],
#  303: ['the'],
#  304: ['deep', ','],
#  305: ['widespread'],
#  306: ['distrust'],
#  307: ['for'],
#  308: ['the'],
#  309: ['Chinese'],
#  310: ['legal'],
#  311: ['system', '.'],
#  312: ['Pro-democracy'],
#  313: ['activists', ','],
#  314: ['NGOs'],
#  315: ['and'],
#  316: ['business'],
#  317: ['groups'],
#  318: ['came'],
#  319: ['together'],
#  320: ['in'],
#  321: ['calling'],
#  322: ['for'],
#  323: ['the'],
#  324: ['bill', "'s"],
#  325: ['withdrawal', ','],
#  326: ['and'],
#  327: ['it'],
#  328: ['also'],
#  329: ['served'],
#  330: ['to'],
#  331: ['unify'],
#  332: ['the'],
#  333: ['previously'],
#  334: ['fractured'],
#  335: ['political'],
#  336: ['opposition', '.'],
#  337: ['Protests'],
#  338: ['this'],
#  339: ['month'],
#  340: ['--'],
#  341: ['with'],
#  342: ['the'],
#  343: ['June'],
#  344: ['9'],
#  345: ['march'],
#  346: ['the'],
#  347: ['largest'],
#  348: ['since'],
#  349: ['Hong'],
#  350: ['Kong'],
#  351: ['was'],
#  352: ['handed'],
#  353: ['over'],
#  354: ['to'],
#  355: ['Chinese'],
#  356: ['control', ','],
#  357: ['and'],
#  358: ['Wednesday', "'s"],
#  359: ['protests'],
#  360: ['among'],
#  361: ['some'],
#  362: ['of'],
#  363: ['the'],
#  364: ['most'],
#  365: ['violent'],
#  366: ['scenes'],
#  367: ['ever'],
#  368: ['seen'],
#  369: ['in'],
#  370: ['the'],
#  371: ['city'],
#  372: ['--'],
#  373: ['left'],
#  374: ['Lam'],
#  375: ['unwilling'],
#  376: ['to'],
#  377: ['push'],
#  378: ['forward'],
#  379: ['with'],
#  380: ['a'],
#  381: ['bill'],
#  382: ['so'],
#  383: ['clearly'],
#  384: ['unpopular'],
#  385: ['and'],
#  386: ['potentially'],
#  387: ['dangerous', '.'],
#  388: ['However', ','],
#  389: ['while'],
#  390: ['the'],
#  391: ['climbdown'],
#  392: ['is'],
#  393: ['certainly'],
#  394: ['embarrassing'],
#  395: ['to'],
#  396: ['both'],
#  397: ['the'],
#  398: ['Hong'],
#  399: ['Kong'],
#  400: ['and'],
#  401: ['Beijing'],
#  402: ['governments', ','],
#  403: ['it'],
#  404: ['only'],
#  405: ['maintains'],
#  406: ['the'],
#  407: ['status'],
#  408: ['quo', ','],
#  409: ['as'],
#  410: ['did'],
#  411: ['a'],
#  412: ['mass'],
#  413: ['movement'],
#  414: ['against'],
#  415: ['an'],
#  416: ['anti-sedition'],
#  417: ['law'],
#  418: ['in'],
#  419: ['2003', ','],
#  420: ['previously'],
#  421: ['the'],
#  422: ['largest'],
#  423: ['protests'],
#  424: ['Hong'],
#  425: ['Kong'],
#  426: ['had'],
#  427: ['seen'],
#  428: ['under'],
#  429: ['Chinese'],
#  430: ['rule', '.'],
#  431: ['Hong'],
#  432: ['Kong'],
#  433: ['residents'],
#  434: ['have'],
#  435: ['proven'],
#  436: ['more'],
#  437: ['willing'],
#  438: ['to'],
#  439: ['come'],
#  440: ['to'],
#  441: ['the'],
#  442: ['streets'],
#  443: ['to'],
#  444: ['fight'],
#  445: ['back'],
#  446: ['against'],
#  447: ['a'],
#  448: ['loss'],
#  449: ['of'],
#  450: ['political'],
#  451: ['freedoms'],
#  452: ['than'],
#  453: ['to'],
#  454: ['push'],
#  455: ['for'],
#  456: ['extra'],
#  457: ['ones', ','],
#  458: ['and'],
#  459: ['both'],
#  460: ['the'],
#  461: ['local'],
#  462: ['and'],
#  463: ['central'],
#  464: ['governments'],
#  465: ['appear'],
#  466: ['to'],
#  467: ['have'],
#  468: ['a'],
#  469: ['greater'],
#  470: ['degree'],
#  471: ['of'],
#  472: ['flexibility'],
#  473: ['or'],
#  474: ['patience'],
#  475: ['on'],
#  476: ['these'],
#  477: ['issues'],
#  478: ['as'],
#  479: ['well', '.'],
#  480: ['The'],
#  481: ['situation'],
#  482: ['in'],
#  483: ['2014', ','],
#  484: ['when'],
#  485: ['demands'],
#  486: ['for'],
#  487: ['the'],
#  488: ['direct'],
#  489: ['election'],
#  490: ['of'],
#  491: ['the'],
#  492: ['chief'],
#  493: ['executive'],
#  494: ['spiraled'],
#  495: ['into'],
#  496: ['the'],
#  497: ['Umbrella'],
#  498: ['Movement', ','],
#  499: ['was'],
#  500: ['very'],
#  501: ['different', '.'],
#  502: ['Those'],
#  503: ['protests'],
#  504: ['did'],
#  505: ['not'],
#  506: ['attract'],
#  507: ['such'],
#  508: ['a'],
#  509: ['broad'],
#  510: ['swath'],
#  511: ['of'],
#  512: ['society', ','],
#  513: ['and'],
#  514: ['they'],
#  515: ['were'],
#  516: ['also'],
#  517: ['greeted'],
#  518: ['with'],
#  519: ['a'],
#  520: ['much'],
#  521: ['more'],
#  522: ['forceful'],
#  523: ['reaction'],
#  524: ['by'],
#  525: ['Beijing', ','],
#  526: ['and'],
#  527: ['a'],
#  528: ['subsequent'],
#  529: ['crackdown'],
#  530: ['and'],
#  531: ['numerous'],
#  532: ['prosecutions'],
#  533: ['and'],
#  534: ['disqualifications'],
#  535: ['of'],
#  536: ['lawmakers', '.'],
#  537: ['Does'],
#  538: ['the'],
#  539: ['bill'],
#  540: ['have'],
#  541: ['a'],
#  542: ['future', '?', 'While'],
#  543: ['Lam'],
#  544: ['emphasized'],
#  545: ['that'],
#  546: ['the'],
#  547: ['bill'],
#  548: ['has'],
#  549: ['been'],
#  550: ['suspended'],
#  551: ['rather'],
#  552: ['than'],
#  553: ['completely'],
#  554: ['withdrawn', ','],
#  555: ['it'],
#  556: ['is'],
#  557: ['likely'],
#  558: ['that'],
#  559: ['the'],
#  560: ['effect'],
#  561: ['will'],
#  562: ['be'],
#  563: ['the'],
#  564: ['same', ','],
#  565: ['at'],
#  566: ['least'],
#  567: ['in'],
#  568: ['the'],
#  569: ['near'],
#  570: ['term', '.'],
#  571: ['As'],
#  572: ['opposition'],
#  573: ['to'],
#  574: ['the'],
#  575: ['bill'],
#  576: ['grew', ','],
#  577: ['Taipei'],
#  578: ['said'],
#  579: ['it'],
#  580: ['would'],
#  581: ['not'],
#  582: ['request'],
#  583: ['the'],
#  584: ['murder'],
#  585: ['suspect', "'s"],
#  586: ['extradition'],
#  587: ['from'],
#  588: ['Hong'],
#  589: ['Kong', ','],
#  590: ['as'],
#  591: ['it'],
#  592: ['said'],
#  593: ['the'],
#  594: ['bill'],
#  595: ['would'],
#  596: ['put'],
#  597: ['Taiwanese'],
#  598: ['citizens'],
#  599: ['in'],
#  600: ['danger', '.'],
#  601: ['With'],
#  602: ['this'],
#  603: ['off'],
#  604: ['the'],
#  605: ['table', ','],
#  606: ['Lam'],
#  607: ['admitted'],
#  608: ['there'],
#  609: ['was'],
#  610: ['``', 'less'],
#  611: ['urgency'],
#  612: ['to'],
#  613: ['pass'],
#  614: ['the'],
#  615: ['bill'],
#  616: ['this'],
#  617: ['year', '.', "''"],
#  618: ['Going'],
#  619: ['forward', ','],
#  620: ['she'],
#  621: ['said'],
#  622: ['she'],
#  623: ['wanted'],
#  624: ['to'],
#  625: ['focus'],
#  626: ['on'],
#  627: ['``', 'economic'],
#  628: ['and'],
#  629: ['livelihood', "''"],
#  630: ['issues', ','],
#  631: ['particularly'],
#  632: ['those'],
#  633: ['such'],
#  634: ['as'],
#  635: ['housing', ','],
#  636: ['a'],
#  637: ['consistent'],
#  638: ['major'],
#  639: ['issue'],
#  640: ['in'],
#  641: ['Hong'],
#  642: ['Kong', ','],
#  643: ['particularly'],
#  644: ['for'],
#  645: ['young'],
#  646: ['people'],
#  647: ['of'],
#  648: ['the'],
#  649: ['sort'],
#  650: ['out'],
#  651: ['protesting'],
#  652: ['Wednesday', '.'],
#  653: ['That'],
#  654: ['language'],
#  655: ['is'],
#  656: ['similar'],
#  657: ['to'],
#  658: ['what'],
#  659: ['she'],
#  660: ['has'],
#  661: ['used'],
#  662: ['in'],
#  663: ['the'],
#  664: ['past'],
#  665: ['when'],
#  666: ['discussing'],
#  667: ['whether'],
#  668: ['her'],
#  669: ['government'],
#  670: ['would'],
#  671: ['seek'],
#  672: ['to'],
#  673: ['introduce'],
#  674: ['Article'],
#  675: ['23', ','],
#  676: ['the'],
#  677: ['anti-sedition'],
#  678: ['law'],
#  679: ['which'],
#  680: ['was'],
#  681: ['shelved'],
#  682: ['after'],
#  683: ['mass'],
#  684: ['protests'],
#  685: ['against'],
#  686: ['it'],
#  687: ['in'],
#  688: ['2003', '.'],
#  689: ['Lam'],
#  690: ['has'],
#  691: ['said'],
#  692: ['she'],
#  693: ['would'],
#  694: ['only'],
#  695: ['do'],
#  696: ['so'],
#  697: ['were'],
#  698: ['the'],
#  699: ['conditions'],
#  700: ['in'],
#  701: ['society'],
#  702: ['correct', ','],
#  703: ['and'],
#  704: ['on'],
#  705: ['Saturday'],
#  706: ['she'],
#  707: ['said'],
#  708: ['she'],
#  709: ['regretted'],
#  710: ['that'],
#  711: ['controversies'],
#  712: ['over'],
#  713: ['the'],
#  714: ['extradition'],
#  715: ['bill'],
#  716: ['had'],
#  717: ['spoiled'],
#  718: ['the'],
#  719: ['``', 'period'],
#  720: ['of'],
#  721: ['calm', "''"],
#  722: ['Hong'],
#  723: ['Kong'],
#  724: ['had'],
#  725: ['enjoyed'],
#  726: ['since'],
#  727: ['she'],
#  728: ['took'],
#  729: ['office'],
#  730: ['in'],
#  731: ['2017', '.'],
#  732: ['While'],
#  733: ['the'],
#  734: ['government'],
#  735: ['could'],
#  736: ['reintroduce'],
#  737: ['the'],
#  738: ['bill'],
#  739: ['next'],
#  740: ['year', ','],
#  741: ['it'],
#  742: ['is'],
#  743: ['unlikely'],
#  744: ['as'],
#  745: ['2020'],
#  746: ['is'],
#  747: ['an'],
#  748: ['election'],
#  749: ['year'],
#  750: ['for'],
#  751: ['the'],
#  752: ['legislative'],
#  753: ['council', '.', 'The'],
#  754: ['newly'],
#  755: ['reinvigorated'],
#  756: ['and'],
#  757: ['unified'],
#  758: ['pro-democratic'],
#  759: ['camp'],
#  760: ['will'],
#  761: ['be'],
#  762: ['targeting'],
#  763: ['marginal'],
#  764: ['seats'],
#  765: ['in'],
#  766: ['an'],
#  767: ['attempt'],
#  768: ['to'],
#  769: ['wrest'],
#  770: ['back'],
#  771: ['veto'],
#  772: ['power'],
#  773: ['in'],
#  774: ['the'],
#  775: ['legislature', ','],
#  776: ['and'],
#  777: ['pro-Beijing'],
#  778: ['lawmakers'],
#  779: ['have'],
#  780: ['already'],
#  781: ['warned'],
#  782: ['that'],
#  783: ['the'],
#  784: ['controversies'],
#  785: ['over'],
#  786: ['the'],
#  787: ['bill'],
#  788: ['could'],
#  789: ['cost'],
#  790: ['them'],
#  791: ['seats', '.'],
#  792: ['So'],
#  793: ['though'],
#  794: ['some'],
#  795: ['protesters'],
#  796: ['and'],
#  797: ['opposition'],
#  798: ['figures'],
#  799: ['may'],
#  800: ['complain'],
#  801: ['that'],
#  802: ['Lam'],
#  803: ['has'],
#  804: ['only'],
#  805: ['suspended'],
#  806: ['rather'],
#  807: ['than'],
#  808: ['withdrawn'],
#  809: ['the'],
#  810: ['bill', ','],
#  811: ['the'],
#  812: ['effect'],
#  813: ['may'],
#  814: ['end'],
#  815: ['up'],
#  816: ['being'],
#  817: ['the'],
#  818: ['same', '.'],
#  819: []}

# %%
token_pos
# Out:
# [('Hong', 'NNP'),
#  ('Kong', 'NNP'),
#  ('(', '('),
#  ('CNN', 'NNP'),
#  (')', ')'),
#  ('Hong', 'NNP'),
#  ('Kong', 'NNP'),
#  ("'s", 'POS'),
#  ('government', 'NN'),
#  ('has', 'VBZ'),
#  ('blinked', 'VBN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('city', 'NN'),
#  ("'s", 'POS'),
#  ('leader', 'NN'),
#  ('Carrie', 'NNP'),
#  ('Lam', 'NNP'),
#  ('announced', 'VBD'),
#  ('Saturday', 'NNP'),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('suspending', 'VBG'),
#  ('a', 'DT'),
#  ('controversial', 'JJ'),
#  ('extradition', 'NN'),
#  ('bill', 'NN'),
#  ('after', 'IN'),
#  ('mass', 'NN'),
#  ('protests', 'NNS'),
#  ('and', 'CC'),
#  ('sustained', 'VBN'),
#  ('opposition', 'NN'),
#  ('from', 'IN'),
#  ('multiple', 'JJ'),
#  ('sectors', 'NNS'),
#  ('of', 'IN'),
#  ('society', 'NN'),
#  ('.', '.'),
#  ('While', 'IN'),
#  ('she', 'PRP'),
#  ('fell', 'VBD'),
#  ('short', 'RB'),
#  ('of', 'IN'),
#  ('fully', 'RB'),
#  ('withdrawing', 'VBG'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  ('--', ':'),
#  ('or', 'CC'),
#  ('resigning', 'VBG'),
#  ('--', ':'),
#  ('as', 'IN'),
#  ('some', 'DT'),
#  ('protesters', 'NNS'),
#  ('had', 'VBD'),
#  ('demand', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('move', 'NN'),
#  ('is', 'VBZ'),
#  ('nevertheless', 'RB'),
#  ('a', 'DT'),
#  ('major', 'JJ'),
#  ('win', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('hundreds', 'NNS'),
#  ('of', 'IN'),
#  ('thousands', 'NNS'),
#  ('who', 'WP'),
#  ('took', 'VBD'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('streets', 'NNS'),
#  ('on', 'IN'),
#  ('June', 'NNP'),
#  ('9', 'CD'),
#  (',', ','),
#  ('as', 'RB'),
#  ('well', 'RB'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('tens', 'NNS'),
#  ('of', 'IN'),
#  ('thousands', 'NNS'),
#  ('of', 'IN'),
#  ('mostly', 'RB'),
#  ('young', 'JJ'),
#  ('protesters', 'NNS'),
#  ('who', 'WP'),
#  ('shut', 'VBP'),
#  ('down', 'RP'),
#  ('parts', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('city', 'NN'),
#  ('on', 'IN'),
#  ('Wednesday', 'NNP'),
#  ('and', 'CC'),
#  ('prevented', 'VBD'),
#  ('lawmakers', 'NNS'),
#  ('from', 'IN'),
#  ('beginning', 'VBG'),
#  ('a', 'DT'),
#  ('second', 'JJ'),
#  ('reading', 'NN'),
#  ('.', '.'),
#  ('Protest', 'JJS'),
#  ('organizers', 'NNS'),
#  ('are', 'VBP'),
#  ('calling', 'VBG'),
#  ('for', 'IN'),
#  ('another', 'DT'),
#  ('mass', 'NN'),
#  ('rally', 'NN'),
#  ('on', 'IN'),
#  ('Sunday', 'NNP'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('bid', 'NN'),
#  ('to', 'TO'),
#  ('keep', 'VB'),
#  ('the', 'DT'),
#  ('pressure', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('government', 'NN'),
#  ('.', '.'),
#  ('Protesters', 'NNS'),
#  ('will', 'MD'),
#  ('wear', 'VB'),
#  ('black', 'JJ'),
#  ('and', 'CC'),
#  ('demand', 'VB'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  ('be', 'VB'),
#  ('completely', 'RB'),
#  ('withdrawn', 'VBN'),
#  ('and', 'CC'),
#  ('Lam', 'NNP'),
#  ('step', 'VB'),
#  ('down', 'RB'),
#  ('.', '.'),
#  ('Pro-democracy', 'JJ'),
#  ('figures', 'NNS'),
#  ('claim', 'VBP'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  ("'s", 'POS'),
#  ('reintroduction', 'NN'),
#  ('would', 'MD'),
#  ('lead', 'VB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('erosion', 'NN'),
#  ('of', 'IN'),
#  ('civil', 'JJ'),
#  ('rights', 'NNS'),
#  ('in', 'IN'),
#  ('Hong', 'NNP'),
#  ('Kong', 'NNP'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('freedom', 'NN'),
#  ('of', 'IN'),
#  ('speech', 'NN'),
#  ('and', 'CC'),
#  ('rule', 'NN'),
#  ('of', 'IN'),
#  ('law', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('could', 'MD'),
#  ('see', 'VB'),
#  ('residents', 'NNS'),
#  ('sent', 'VBN'),
#  ('to', 'TO'),
#  ('China', 'NNP'),
#  ('to', 'TO'),
#  ('face', 'VB'),
#  ('prosecution', 'NN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('country', 'NN'),
#  ('with', 'IN'),
#  ('an', 'DT'),
#  ('opaque', 'JJ'),
#  ('legal', 'JJ'),
#  ('system', 'NN'),
#  ('.', '.'),
#  ('Beijing', 'NNP'),
#  ('has', 'VBZ'),
#  ('yet', 'RB'),
#  ('to', 'TO'),
#  ('officially', 'RB'),
#  ('react', 'VB'),
#  ('to', 'TO'),
#  ('Lam', 'NNP'),
#  ("'s", 'POS'),
#  ('announcement', 'NN'),
#  ('that', 'IN'),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('suspending', 'VBG'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  (',', ','),
#  ('though', 'IN'),
#  ('the', 'DT'),
#  ('Chief', 'NNP'),
#  ('Executive', 'NNP'),
#  ('has', 'VBZ'),
#  ('emphasized', 'VBN'),
#  ('that', 'IN'),
#  ('she', 'PRP'),
#  ('had', 'VBD'),
#  ('the', 'DT'),
#  ('central', 'JJ'),
#  ('government', 'NN'),
#  ("'s", 'POS'),
#  ('support', 'NN'),
#  ('.', '.'),
#  ('From', 'IN'),
#  ('all', 'DT'),
#  ('available', 'JJ'),
#  ('accounts', 'NNS'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('appears', 'VBZ'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  ('was', 'VBD'),
#  ('an', 'DT'),
#  ('initiative', 'NN'),
#  ('of', 'IN'),
#  ('Lam', 'NNP'),
#  ("'s", 'POS'),
#  ('government', 'NN'),
#  ('--', ':'),
#  ('as', 'IN'),
#  ('she', 'PRP'),
#  ('has', 'VBZ'),
#  ('claimed', 'VBN'),
#  ('all', 'RB'),
#  ('along', 'RB'),
#  ('--', ':'),
#  ('rather', 'RB'),
#  ('than', 'IN'),
#  ('an', 'DT'),
#  ('order', 'NN'),
#  ('from', 'IN'),
#  ('on', 'IN'),
#  ('high', 'JJ'),
#  ('.', '.'),
#  ('Lam', 'NNP'),
#  ('and', 'CC'),
#  ('her', 'PRP$'),
#  ('ministers', 'NNS'),
#  ('appear', 'VBP'),
#  ('to', 'TO'),
#  ('have', 'VB'),
#  ('seen', 'VBN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('gruesome', 'JJ'),
#  ('Taiwan', 'NNP'),
#  ('murder', 'NN'),
#  ('case', 'NN'),
#  ('a', 'DT'),
#  ('way', 'NN'),
#  ('to', 'TO'),
#  ('win', 'VB'),
#  ('an', 'DT'),
#  ('easy', 'JJ'),
#  ('public', 'JJ'),
#  ('relations', 'NNS'),
#  ('victory', 'NN'),
#  ('by', 'IN'),
#  ('extraditing', 'VBG'),
#  ('a', 'DT'),
#  ('wanted', 'JJ'),
#  ('killer', 'NN'),
#  ('to', 'TO'),
#  ('face', 'NN'),
#  ('justice', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('way', 'NN'),
#  ('to', 'TO'),
#  ('close', 'VB'),
#  ('loopholes', 'NNS'),
#  ('and', 'CC'),
#  ('extend', 'VB'),
#  ('the', 'DT'),
#  ('central', 'JJ'),
#  ('government', 'NN'),
#  ("'s", 'POS'),
#  ('powers', 'NNS'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('after', 'IN'),
#  ('fugitives', 'NNS'),
#  (',', ','),
#  ('especially', 'RB'),
#  ('former', 'JJ'),
#  ('Chinese', 'JJ'),
#  ('officials', 'NNS'),
#  (',', ','),
#  ('in', 'IN'),
#  ('Hong', 'NNP'),
#  ('Kong', 'NNP'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('do', 'VBP'),
#  ('not', 'RB'),
#  (',', ','),
#  ('however', 'RB'),
#  (',', ','),
#  ('seem', 'VBP'),
#  ('to', 'TO'),
#  ('have', 'VB'),
#  ('expected', 'VBN'),
#  ('the', 'DT'),
#  ('overwhelmingly', 'RB'),
#  ('negative', 'JJ'),
#  ('response', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('deep', 'JJ'),
#  (',', ','),
#  ('widespread', 'JJ'),
#  ('distrust', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('Chinese', 'JJ'),
#  ('legal', 'JJ'),
#  ('system', 'NN'),
#  ('.', '.'),
#  ('Pro-democracy', 'JJ'),
#  ('activists', 'NNS'),
#  (',', ','),
#  ('NGOs', 'NNP'),
#  ('and', 'CC'),
#  ('business', 'NN'),
#  ('groups', 'NNS'),
#  ('came', 'VBD'),
#  ('together', 'RB'),
#  ('in', 'IN'),
#  ('calling', 'VBG'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  ("'s", 'POS'),
#  ('withdrawal', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('it', 'PRP'),
#  ('also', 'RB'),
#  ('served', 'VBD'),
#  ('to', 'TO'),
#  ('unify', 'VB'),
#  ('the', 'DT'),
#  ('previously', 'RB'),
#  ('fractured', 'VBN'),
#  ('political', 'JJ'),
#  ('opposition', 'NN'),
#  ('.', '.'),
#  ('Protests', 'NNS'),
#  ('this', 'DT'),
#  ('month', 'NN'),
#  ('--', ':'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('June', 'NNP'),
#  ('9', 'CD'),
#  ('march', 'NN'),
#  ('the', 'DT'),
#  ('largest', 'JJS'),
#  ('since', 'IN'),
#  ('Hong', 'NNP'),
#  ('Kong', 'NNP'),
#  ('was', 'VBD'),
#  ('handed', 'VBN'),
#  ('over', 'RP'),
#  ('to', 'TO'),
#  ('Chinese', 'JJ'),
#  ('control', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('Wednesday', 'NNP'),
#  ("'s", 'POS'),
#  ('protests', 'NNS'),
#  ('among', 'IN'),
#  ('some', 'DT'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('violent', 'JJ'),
#  ('scenes', 'NNS'),
#  ('ever', 'RB'),
#  ('seen', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('city', 'NN'),
#  ('--', ':'),
#  ('left', 'VBD'),
#  ('Lam', 'NNP'),
#  ('unwilling', 'JJ'),
#  ('to', 'TO'),
#  ('push', 'VB'),
#  ('forward', 'RB'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('bill', 'NN'),
#  ('so', 'RB'),
#  ('clearly', 'RB'),
#  ('unpopular', 'JJ'),
#  ('and', 'CC'),
#  ('potentially', 'RB'),
#  ('dangerous', 'JJ'),
#  ('.', '.'),
#  ('However', 'RB'),
#  (',', ','),
#  ('while', 'IN'),
#  ('the', 'DT'),
#  ('climbdown', 'NN'),
#  ('is', 'VBZ'),
#  ('certainly', 'RB'),
#  ('embarrassing', 'VBG'),
#  ('to', 'TO'),
#  ('both', 'DT'),
#  ('the', 'DT'),
#  ('Hong', 'NNP'),
#  ('Kong', 'NNP'),
#  ('and', 'CC'),
#  ('Beijing', 'NNP'),
#  ('governments', 'NNS'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('only', 'RB'),
#  ('maintains', 'VBZ'),
#  ('the', 'DT'),
#  ('status', 'NN'),
#  ('quo', 'NN'),
#  (',', ','),
#  ('as', 'IN'),
#  ('did', 'VBD'),
#  ('a', 'DT'),
#  ('mass', 'NN'),
#  ('movement', 'NN'),
#  ('against', 'IN'),
#  ('an', 'DT'),
#  ('anti-sedition', 'JJ'),
#  ('law', 'NN'),
#  ('in', 'IN'),
#  ('2003', 'CD'),
#  (',', ','),
#  ('previously', 'RB'),
#  ('the', 'DT'),
#  ('largest', 'JJS'),
#  ('protests', 'NNS'),
#  ('Hong', 'NNP'),
#  ('Kong', 'NNP'),
#  ('had', 'VBD'),
#  ('seen', 'VBN'),
#  ('under', 'IN'),
#  ('Chinese', 'JJ'),
#  ('rule', 'NN'),
#  ('.', '.'),
#  ('Hong', 'NNP'),
#  ('Kong', 'NNP'),
#  ('residents', 'NNS'),
#  ('have', 'VBP'),
#  ('proven', 'VBN'),
#  ('more', 'RBR'),
#  ('willing', 'JJ'),
#  ('to', 'TO'),
#  ('come', 'VB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('streets', 'NNS'),
#  ('to', 'TO'),
#  ('fight', 'VB'),
#  ('back', 'RB'),
#  ('against', 'IN'),
#  ('a', 'DT'),
#  ('loss', 'NN'),
#  ('of', 'IN'),
#  ('political', 'JJ'),
#  ('freedoms', 'NNS'),
#  ('than', 'IN'),
#  ('to', 'TO'),
#  ('push', 'VB'),
#  ('for', 'IN'),
#  ('extra', 'JJ'),
#  ('ones', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('both', 'DT'),
#  ('the', 'DT'),
#  ('local', 'JJ'),
#  ('and', 'CC'),
#  ('central', 'JJ'),
#  ('governments', 'NNS'),
#  ('appear', 'VBP'),
#  ('to', 'TO'),
#  ('have', 'VB'),
#  ('a', 'DT'),
#  ('greater', 'JJR'),
#  ('degree', 'NN'),
#  ('of', 'IN'),
#  ('flexibility', 'NN'),
#  ('or', 'CC'),
#  ('patience', 'NN'),
#  ('on', 'IN'),
#  ('these', 'DT'),
#  ('issues', 'NNS'),
#  ('as', 'RB'),
#  ('well', 'RB'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('situation', 'NN'),
#  ('in', 'IN'),
#  ('2014', 'CD'),
#  (',', ','),
#  ('when', 'WRB'),
#  ('demands', 'NNS'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('direct', 'JJ'),
#  ('election', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('chief', 'JJ'),
#  ('executive', 'NN'),
#  ('spiraled', 'VBD'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('Umbrella', 'NNP'),
#  ('Movement', 'NNP'),
#  (',', ','),
#  ('was', 'VBD'),
#  ('very', 'RB'),
#  ('different', 'JJ'),
#  ('.', '.'),
#  ('Those', 'DT'),
#  ('protests', 'NNS'),
#  ('did', 'VBD'),
#  ('not', 'RB'),
#  ('attract', 'VB'),
#  ('such', 'JJ'),
#  ('a', 'DT'),
#  ('broad', 'JJ'),
#  ('swath', 'NN'),
#  ('of', 'IN'),
#  ('society', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('they', 'PRP'),
#  ('were', 'VBD'),
#  ('also', 'RB'),
#  ('greeted', 'VBN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('much', 'RB'),
#  ('more', 'RBR'),
#  ('forceful', 'JJ'),
#  ('reaction', 'NN'),
#  ('by', 'IN'),
#  ('Beijing', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('subsequent', 'JJ'),
#  ('crackdown', 'NN'),
#  ('and', 'CC'),
#  ('numerous', 'JJ'),
#  ('prosecutions', 'NNS'),
#  ('and', 'CC'),
#  ('disqualifications', 'NNS'),
#  ('of', 'IN'),
#  ('lawmakers', 'NNS'),
#  ('.', '.'),
#  ('Does', 'VBZ'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  ('have', 'VBP'),
#  ('a', 'DT'),
#  ('future', 'NN'),
#  ('?', '.'),
#  ('While', 'IN'),
#  ('Lam', 'NNP'),
#  ('emphasized', 'VBD'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('suspended', 'VBN'),
#  ('rather', 'RB'),
#  ('than', 'IN'),
#  ('completely', 'RB'),
#  ('withdrawn', 'VBN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('likely', 'JJ'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('effect', 'NN'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  (',', ','),
#  ('at', 'IN'),
#  ('least', 'JJS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('near', 'JJ'),
#  ('term', 'NN'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('opposition', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  ('grew', 'VBD'),
#  (',', ','),
#  ('Taipei', 'NNP'),
#  ('said', 'VBD'),
#  ('it', 'PRP'),
#  ('would', 'MD'),
#  ('not', 'RB'),
#  ('request', 'VB'),
#  ('the', 'DT'),
#  ('murder', 'NN'),
#  ('suspect', 'NN'),
#  ("'s", 'POS'),
#  ('extradition', 'NN'),
#  ('from', 'IN'),
#  ('Hong', 'NNP'),
#  ('Kong', 'NNP'),
#  (',', ','),
#  ('as', 'IN'),
#  ('it', 'PRP'),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  ('would', 'MD'),
#  ('put', 'VB'),
#  ('Taiwanese', 'JJ'),
#  ('citizens', 'NNS'),
#  ('in', 'IN'),
#  ('danger', 'NN'),
#  ('.', '.'),
#  ('With', 'IN'),
#  ('this', 'DT'),
#  ('off', 'RP'),
#  ('the', 'DT'),
#  ('table', 'NN'),
#  (',', ','),
#  ('Lam', 'NNP'),
#  ('admitted', 'VBD'),
#  ('there', 'EX'),
#  ('was', 'VBD'),
#  ('``', '``'),
#  ('less', 'JJR'),
#  ('urgency', 'NN'),
#  ('to', 'TO'),
#  ('pass', 'VB'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  ('this', 'DT'),
#  ('year', 'NN'),
#  ('.', '.'),
#  ("''", "''"),
#  ('Going', 'VBG'),
#  ('forward', 'RB'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('said', 'VBD'),
#  ('she', 'PRP'),
#  ('wanted', 'VBD'),
#  ('to', 'TO'),
#  ('focus', 'VB'),
#  ('on', 'IN'),
#  ('``', '``'),
#  ('economic', 'JJ'),
#  ('and', 'CC'),
#  ('livelihood', 'NN'),
#  ("''", "''"),
#  ('issues', 'NNS'),
#  (',', ','),
#  ('particularly', 'RB'),
#  ('those', 'DT'),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('housing', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('consistent', 'JJ'),
#  ('major', 'JJ'),
#  ('issue', 'NN'),
#  ('in', 'IN'),
#  ('Hong', 'NNP'),
#  ('Kong', 'NNP'),
#  (',', ','),
#  ('particularly', 'RB'),
#  ('for', 'IN'),
#  ('young', 'JJ'),
#  ('people', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('sort', 'NN'),
#  ('out', 'RP'),
#  ('protesting', 'NN'),
#  ('Wednesday', 'NNP'),
#  ('.', '.'),
#  ('That', 'DT'),
#  ('language', 'NN'),
#  ('is', 'VBZ'),
#  ('similar', 'JJ'),
#  ('to', 'TO'),
#  ('what', 'WP'),
#  ('she', 'PRP'),
#  ('has', 'VBZ'),
#  ('used', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('past', 'NN'),
#  ('when', 'WRB'),
#  ('discussing', 'VBG'),
#  ('whether', 'IN'),
#  ('her', 'PRP$'),
#  ('government', 'NN'),
#  ('would', 'MD'),
#  ('seek', 'VB'),
#  ('to', 'TO'),
#  ('introduce', 'VB'),
#  ('Article', 'NNP'),
#  ('23', 'CD'),
#  (',', ','),
#  ('the', 'DT'),
#  ('anti-sedition', 'NN'),
#  ('law', 'NN'),
#  ('which', 'WDT'),
#  ('was', 'VBD'),
#  ('shelved', 'VBN'),
#  ('after', 'IN'),
#  ('mass', 'NN'),
#  ('protests', 'NNS'),
#  ('against', 'IN'),
#  ('it', 'PRP'),
#  ('in', 'IN'),
#  ('2003', 'CD'),
#  ('.', '.'),
#  ('Lam', 'NNP'),
#  ('has', 'VBZ'),
#  ('said', 'VBD'),
#  ('she', 'PRP'),
#  ('would', 'MD'),
#  ('only', 'RB'),
#  ('do', 'VB'),
#  ('so', 'RB'),
#  ('were', 'VBD'),
#  ('the', 'DT'),
#  ('conditions', 'NNS'),
#  ('in', 'IN'),
#  ('society', 'NN'),
#  ('correct', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('on', 'IN'),
#  ('Saturday', 'NNP'),
#  ('she', 'PRP'),
#  ('said', 'VBD'),
#  ('she', 'PRP'),
#  ('regretted', 'VBD'),
#  ('that', 'IN'),
#  ('controversies', 'NNS'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('extradition', 'NN'),
#  ('bill', 'NN'),
#  ('had', 'VBD'),
#  ('spoiled', 'VBN'),
#  ('the', 'DT'),
#  ('``', '``'),
#  ('period', 'NN'),
#  ('of', 'IN'),
#  ('calm', 'JJ'),
#  ("''", "''"),
#  ('Hong', 'NNP'),
#  ('Kong', 'NNP'),
#  ('had', 'VBD'),
#  ('enjoyed', 'VBN'),
#  ('since', 'IN'),
#  ('she', 'PRP'),
#  ('took', 'VBD'),
#  ('office', 'NN'),
#  ('in', 'IN'),
#  ('2017', 'CD'),
#  ('.', '.'),
#  ('While', 'IN'),
#  ('the', 'DT'),
#  ('government', 'NN'),
#  ('could', 'MD'),
#  ('reintroduce', 'VB'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  ('next', 'JJ'),
#  ('year', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('unlikely', 'JJ'),
#  ('as', 'IN'),
#  ('2020', 'CD'),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('election', 'NN'),
#  ('year', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('legislative', 'JJ'),
#  ('council', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('newly', 'RB'),
#  ('reinvigorated', 'VBN'),
#  ('and', 'CC'),
#  ('unified', 'VBN'),
#  ('pro-democratic', 'JJ'),
#  ('camp', 'NN'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('targeting', 'VBG'),
#  ('marginal', 'JJ'),
#  ('seats', 'NNS'),
#  ('in', 'IN'),
#  ('an', 'DT'),
#  ('attempt', 'NN'),
#  ('to', 'TO'),
#  ('wrest', 'VB'),
#  ('back', 'RB'),
#  ('veto', 'NN'),
#  ('power', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('legislature', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('pro-Beijing', 'JJ'),
#  ('lawmakers', 'NNS'),
#  ('have', 'VBP'),
#  ('already', 'RB'),
#  ('warned', 'VBN'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('controversies', 'NNS'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  ('could', 'MD'),
#  ('cost', 'VB'),
#  ('them', 'PRP'),
#  ('seats', 'NNS'),
#  ('.', '.'),
#  ('So', 'NNP'),
#  ('though', 'IN'),
#  ('some', 'DT'),
#  ('protesters', 'NNS'),
#  ('and', 'CC'),
#  ('opposition', 'NN'),
#  ('figures', 'NNS'),
#  ('may', 'MD'),
#  ('complain', 'VB'),
#  ('that', 'DT'),
#  ('Lam', 'NNP'),
#  ('has', 'VBZ'),
#  ('only', 'RB'),
#  ('suspended', 'VBN'),
#  ('rather', 'RB'),
#  ('than', 'IN'),
#  ('withdrawn', 'VB'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('effect', 'NN'),
#  ('may', 'MD'),
#  ('end', 'VB'),
#  ('up', 'RP'),
#  ('being', 'VBG'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  ('.', '.')]

# %% [markdown]
# # Read glove embedding file

# %%
model = KeyedVectors.load_word2vec_format(os.getcwd()+"/glove_300d_word2vec.txt")

# %% [markdown]
# # Read English 5000 vocabulary dictionary file

# %%
#read Oxford 5000 vocabulary from file
f = open('5000_voc_Oxford.txt','r')
words_5000 = []
for line in f.readlines():
    line = line.lower()
    line = line.strip('\n')
    line = line.split('\t',1)
    words_5000.append([line[0]])
f.close()

# %% [markdown]
# ## Read input paragraph file (Optional, or you can use CNN url to read paragraph)

# %%
f = open('input.txt','r')
origin = f.read()

# %% [markdown]
# ## Read input CNN paragraph URL

# %%
CNN_URL = 'https://edition.cnn.com/2019/06/15/asia/hong-kong-extradition-law-china-intl-hnk/index.html'
origin = crawlCNN(CNN_URL)

# %% [markdown]
# # Preprocess the paragraph

# %%
print('Origin paragraph:')
print(origin,'\n')
# paragraph is a list of origin paragraph split by ' '
paragraph = origin.split(' ')

#token_pos => [('Tokyo', 'NNP'), ('(', '('), ('CNN', 'NNP'), (')', ')'), ('Japan', 'NNP'), ("'s", 'POS'), ....]
token_pos = nltk.pos_tag(nltk.word_tokenize(origin))

#word_token => dictionary with key = paragraph's index, value = word_tokenize(value of paragraph)
#word_token => {0: ['Tokyo'], 1:['(', 'CNN', ')', 'Japan', "'s"], 2:['85-year-old'], ....}
word_token = {}
for index, token in enumerate(paragraph):
    word_token[index] = nltk.word_tokenize(token)

#list of (word_token's index, pos, original token, origina token's lower and simple tense || original token)
#allword => [(0, 'NNP', 'Tokyo', 'Tokyo'), (1, '(', '(', '('), (1, 'NNP', 'CNN', 'CNN'), .....]
allword = []
verb_pos = ['VBD','VBG','VBN','VBP','VBZ']
noun_pos = ['NNS']
posIndex = 0
for key, value in word_token.items():
    for v in value:
        if posIndex >= len(token_pos):
            break
        current_pos = token_pos[posIndex][1]
        #simplify the word tense of V. and N.
        if current_pos in verb_pos:
            word = (key, current_pos, v, WordNetLemmatizer().lemmatize(v.lower(),'v'))
            allword.append(word) 
        elif current_pos in noun_pos:
            word = (key, current_pos, v, WordNetLemmatizer().lemmatize(v.lower(),'n'))
            allword.append(word)
        else:
            word = (key, current_pos, v, v)
            allword.append(word)
        posIndex += 1
# Out:
# Origin paragraph:
# Hong Kong (CNN)Hong Kong's government has blinked. The city's leader Carrie Lam announced Saturday she was suspending a controversial extradition bill after mass protests and sustained opposition from multiple sectors of society.
# While she fell short of fully withdrawing the bill -- or resigning -- as some protesters had demand, the move is nevertheless a major win for the hundreds of thousands who took to the streets on June 9, as well as the tens of thousands of mostly young protesters who shut down parts of the city on Wednesday and prevented lawmakers from beginning a second reading.
# Protest organizers are calling for another mass rally on Sunday in a bid to keep the pressure on the government. Protesters will wear black and demand the bill be completely withdrawn and Lam step down.
# Pro-democracy figures claim the bill's reintroduction would lead to the erosion of civil rights in Hong Kong, including freedom of speech and rule of law, and could see residents sent to China to face prosecution in a country with an opaque legal system.
# Beijing has yet to officially react to Lam's announcement that she was suspending the bill, though the Chief Executive has emphasized that she had the central government's support.
# From all available accounts, it appears that the bill was an initiative of Lam's government -- as she has claimed all along -- rather than an order from on high.
# Lam and her ministers appear to have seen in a gruesome Taiwan murder case a way to win an easy public relations victory by extraditing a wanted killer to face justice, and a way to close loopholes and extend the central government's powers to go after fugitives, especially former Chinese officials, in Hong Kong.
# They do not, however, seem to have expected the overwhelmingly negative response to the bill and the deep, widespread distrust for the Chinese legal system. Pro-democracy activists, NGOs and business groups came together in calling for the bill's withdrawal, and it also served to unify the previously fractured political opposition.
# Protests this month -- with the June 9 march the largest since Hong Kong was handed over to Chinese control, and Wednesday's protests among some of the most violent scenes ever seen in the city -- left Lam unwilling to push forward with a bill so clearly unpopular and potentially dangerous.
# However, while the climbdown is certainly embarrassing to both the Hong Kong and Beijing governments, it only maintains the status quo, as did a mass movement against an anti-sedition law in 2003, previously the largest protests Hong Kong had seen under Chinese rule.
# Hong Kong residents have proven more willing to come to the streets to fight back against a loss of political freedoms than to push for extra ones, and both the local and central governments appear to have a greater degree of flexibility or patience on these issues as well.
# The situation in 2014, when demands for the direct election of the chief executive spiraled into the Umbrella Movement, was very different. Those protests did not attract such a broad swath of society, and they were also greeted with a much more forceful reaction by Beijing, and a subsequent crackdown and numerous prosecutions and disqualifications of lawmakers.
# Does the bill have a future?
# While Lam emphasized that the bill has been suspended rather than completely withdrawn, it is likely that the effect will be the same, at least in the near term.
# As opposition to the bill grew, Taipei said it would not request the murder suspect's extradition from Hong Kong, as it said the bill would put Taiwanese citizens in danger. With this off the table, Lam admitted there was "less urgency to pass the bill this year."
# Going forward, she said she wanted to focus on "economic and livelihood" issues, particularly those such as housing, a consistent major issue in Hong Kong, particularly for young people of the sort out protesting Wednesday.
# That language is similar to what she has used in the past when discussing whether her government would seek to introduce Article 23, the anti-sedition law which was shelved after mass protests against it in 2003. Lam has said she would only do so were the conditions in society correct, and on Saturday she said she regretted that controversies over the extradition bill had spoiled the "period of calm" Hong Kong had enjoyed since she took office in 2017.
# While the government could reintroduce the bill next year, it is unlikely as 2020 is an election year for the legislative council.
# The newly reinvigorated and unified pro-democratic camp will be targeting marginal seats in an attempt to wrest back veto power in the legislature, and pro-Beijing lawmakers have already warned that the controversies over the bill could cost them seats.
# So though some protesters and opposition figures may complain that Lam has only suspended rather than withdrawn the bill, the effect may end up being the same.

# %% [markdown]
# # Find difficult words and find the simpler word to replace it.
# ## All difficult words and the simpler words are stored in variable "diffWord "

# %%
ling = Linggle()
#the POS we check whether the word is difficult.
care_pos = ['NN', 'NN', 'NNS', 'VB', 'VBD', 'VBG', 'VBN', 'VBP',' VBZ']
#print('Difficult words:')
diffWord = []
dont_care_word = ['``', ',', '.', "'d", "'s", "''"]
for word in allword:
    if word[2] in dont_care_word or word[3] in dont_care_word:
        continue
    if word[3] not in [i[0] for i in words_5000] and word[3].lower() not in [i[0] for i in words_5000] and word[1] in care_pos:
        try:
            count = sum([row[1] for row in ling[word[2]+" _"]][:10]) + sum([row[1] for row in ling["_ "+word[2]]][:10])
        except:
            continue
        #如果字在linggle的次數大於150萬，就篩掉，不視為困難字
        if count < 1500000:
            #==================== 用word embedding換同義字 ==========================
            #similar word => 用word embedding前十相近的字挑出分數大於0.6的
            try:
                similar_word = [row[0] for row in model.most_similar(word[2], topn=10) if row[1] > 0.6]
                max_count = 0
                max_word = word[2]
                for s_word in similar_word:
                    s_count = sum([row[1] for row in ling[s_word+" _"]][:10]) + sum([row[1] for row in ling["_ "+s_word]][:10])
                    #從similar word挑出在linggle次數最多的，且次數必須大於原字的2倍，且次數要大於120萬
                    if s_count > (2*count) and s_count > max_count and s_count > 1200000:
                        max_count = s_count
                        max_word = s_word
                if word[2] != max_word:
                    word = word+(max_word, 'word embedding')
                    diffWord.append(word)
                #=============== 如果沒利用word embedding換字，則使用power thesaurus網佔找同義字 =================
                else:
                    replace_word = synonymsPT(word[2])
                    if replace_word == word[2] or replace_word == word[3]:
                        continue
                    else:
                        word = word + (replace_word, 'PT website')
                        diffWord.append(word)
            except:
                continue
# Out:
# /anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
diffWord
# Out:
# [(19, 'NN', 'extradition', 'extradition', 'surrender', 'PT website'),
#  (92, 'NNS', 'lawmakers', 'lawmaker', 'legislation', 'word embedding'),
#  (269, 'NNS', 'loopholes', 'loophole', 'shortcomings', 'PT website'),
#  (306, 'NN', 'distrust', 'distrust', 'dislike', 'word embedding'),
#  (334, 'VBN', 'fractured', 'fracture', 'broken', 'word embedding'),
#  (510, 'NN', 'swath', 'swath', 'path', 'PT website'),
#  (529, 'NN', 'crackdown', 'crackdown', 'protests', 'word embedding'),
#  (536, 'NNS', 'lawmakers', 'lawmaker', 'legislation', 'word embedding'),
#  (586, 'NN', 'extradition', 'extradition', 'surrender', 'PT website'),
#  (629, 'NN', 'livelihood', 'livelihood', 'support', 'PT website'),
#  (651, 'NN', 'protesting', 'protesting', 'protest', 'word embedding'),
#  (681, 'VBN', 'shelved', 'shelve', 'filed', 'PT website'),
#  (714, 'NN', 'extradition', 'extradition', 'surrender', 'PT website'),
#  (736, 'VB', 'reintroduce', 'reintroduce', 'restore', 'PT website'),
#  (755, 'VBN', 'reinvigorated', 'reinvigorate', 'fresh', 'PT website'),
#  (769, 'VB', 'wrest', 'wrest', 'extract', 'PT website'),
#  (771, 'NN', 'veto', 'veto', 'override', 'word embedding'),
#  (778, 'NNS', 'lawmakers', 'lawmaker', 'legislation', 'word embedding')]

# %%
allword
# Out:
# [(0, 'NNP', 'Tokyo', 'Tokyo'),
#  (1, '(', '(', '('),
#  (1, 'NNP', 'CNN', 'CNN'),
#  (1, ')', ')', ')'),
#  (1, 'NNP', 'Japan', 'Japan'),
#  (1, 'POS', "'s", "'s"),
#  (2, 'JJ', '85-year-old', '85-year-old'),
#  (3, 'NN', 'monarch', 'monarch'),
#  (4, 'VBD', 'was', 'be'),
#  (5, 'VBN', 'born', 'bear'),
#  (6, 'DT', 'the', 'the'),
#  (7, 'NN', 'son', 'son'),
#  (8, 'IN', 'of', 'of'),
#  (9, 'DT', 'a', 'a'),
#  (10, 'NN', 'deity', 'deity'),
#  (10, ',', ',', ','),
#  (11, 'CC', 'but', 'but'),
#  (12, 'PRP', 'he', 'he'),
#  (12, 'VBZ', "'s", "'s"),
#  (13, 'VBG', 'retiring', 'retire'),
#  (14, 'IN', 'as', 'as'),
#  (15, 'DT', 'the', 'the'),
#  (16, 'NNS', 'people', 'people'),
#  (16, 'POS', "'s", "'s"),
#  (17, 'NNP', 'Emperor', 'Emperor'),
#  (17, '.', '.', '.'),
#  (17, 'IN', 'On', 'On'),
#  (18, 'NNP', 'Tuesday', 'Tuesday'),
#  (18, ',', ',', ','),
#  (19, 'NNP', 'Emperor', 'Emperor'),
#  (20, 'NNP', 'Akihito', 'Akihito'),
#  (21, 'MD', 'will', 'will'),
#  (22, 'VB', 'abdicate', 'abdicate'),
#  (23, 'DT', 'the', 'the'),
#  (24, 'NNP', 'Chrysanthemum', 'Chrysanthemum'),
#  (25, 'NNP', 'Throne', 'Throne'),
#  (26, ':', '--', '--'),
#  (27, 'DT', 'the', 'the'),
#  (28, 'JJS', 'oldest', 'oldest'),
#  (29, 'JJ', 'continuous', 'continuous'),
#  (30, 'JJ', 'hereditary', 'hereditary'),
#  (31, 'NN', 'monarchy', 'monarchy'),
#  (32, 'IN', 'in', 'in'),
#  (33, 'DT', 'the', 'the'),
#  (34, 'NN', 'world', 'world'),
#  (35, ':', '--', '--'),
#  (36, 'VBG', 'becoming', 'become'),
#  (37, 'DT', 'the', 'the'),
#  (38, 'JJ', 'first', 'first'),
#  (39, 'JJ', 'Japanese', 'Japanese'),
#  (40, 'NN', 'monarch', 'monarch'),
#  (41, 'IN', 'in', 'in'),
#  (42, 'JJ', 'modern', 'modern'),
#  (43, 'NN', 'history', 'history'),
#  (44, 'TO', 'to', 'to'),
#  (45, 'VB', 'do', 'do'),
#  (46, 'RB', 'so', 'so'),
#  (46, '.', '.', '.'),
#  (47, 'PRP$', 'His', 'His'),
#  (48, 'NN', 'son', 'son'),
#  (48, ',', ',', ','),
#  (49, 'NNP', 'Crown', 'Crown'),
#  (50, 'NNP', 'Prince', 'Prince'),
#  (51, 'NNP', 'Naruhito', 'Naruhito'),
#  (51, ',', ',', ','),
#  (52, 'CD', '59', '59'),
#  (52, ',', ',', ','),
#  (53, 'MD', 'will', 'will'),
#  (54, 'VB', 'be', 'be'),
#  (55, 'VBN', 'inaugurated', 'inaugurate'),
#  (56, 'IN', 'as', 'as'),
#  (57, 'DT', 'the', 'the'),
#  (58, 'CD', '126th', '126th'),
#  (59, 'NN', 'emperor', 'emperor'),
#  (60, 'DT', 'the', 'the'),
#  (61, 'JJ', 'next', 'next'),
#  (62, 'NN', 'day', 'day'),
#  (62, ',', ',', ','),
#  (63, 'VBG', 'ushering', 'usher'),
#  (64, 'IN', 'in', 'in'),
#  (65, 'DT', 'the', 'the'),
#  (66, 'NNP', 'Reiwa', 'Reiwa'),
#  (67, 'NN', 'era', 'era'),
#  (67, '.', '.', '.'),
#  (67, 'DT', 'The', 'The'),
#  (68, 'JJ', 'much-loved', 'much-loved'),
#  (69, 'NNP', 'Emperor', 'Emperor'),
#  (70, 'NNP', 'Akihito', 'Akihito'),
#  (71, 'MD', 'will', 'will'),
#  (72, 'VB', 'be', 'be'),
#  (73, 'VBN', 'remembered', 'remember'),
#  (74, 'IN', 'for', 'for'),
#  (75, 'VBG', 'connecting', 'connect'),
#  (76, 'IN', 'with', 'with'),
#  (77, 'PRP$', 'his', 'his'),
#  (78, 'NN', 'public', 'public'),
#  (79, 'IN', 'in', 'in'),
#  (80, 'DT', 'a', 'a'),
#  (81, 'NN', 'way', 'way'),
#  (82, 'IN', 'that', 'that'),
#  (83, 'DT', 'no', 'no'),
#  (84, 'JJ', 'other', 'other'),
#  (85, 'JJ', 'Japanese', 'Japanese'),
#  (86, 'NN', 'monarch', 'monarch'),
#  (87, 'VBZ', 'has', 'have'),
#  (88, 'VBN', 'done', 'do'),
#  (89, 'CC', 'and', 'and'),
#  (90, 'VBG', 'expressing', 'express'),
#  (91, '``', '``', '``'),
#  (91, 'JJ', 'deep', 'deep'),
#  (92, 'NN', 'remorse', 'remorse'),
#  (92, "''", "''", "''"),
#  (93, 'IN', 'for', 'for'),
#  (94, 'DT', 'the', 'the'),
#  (95, 'NN', 'country', 'country'),
#  (95, 'POS', "'s", "'s"),
#  (96, 'NNS', 'actions', 'action'),
#  (97, 'IN', 'during', 'during'),
#  (98, 'NNP', 'World', 'World'),
#  (99, 'NNP', 'War', 'War'),
#  (100, 'NNP', 'II', 'II'),
#  (100, '.', '.', '.'),
#  (100, 'IN', 'After', 'After'),
#  (101, 'VBG', 'having', 'have'),
#  (102, 'NN', 'heart', 'heart'),
#  (103, 'NN', 'surgery', 'surgery'),
#  (104, 'CC', 'and', 'and'),
#  (105, 'VBG', 'overcoming', 'overcome'),
#  (106, 'NN', 'prostate', 'prostate'),
#  (107, 'NN', 'cancer', 'cancer'),
#  (108, 'IN', 'in', 'in'),
#  (109, 'JJ', 'recent', 'recent'),
#  (110, 'NNS', 'years', 'year'),
#  (110, ',', ',', ','),
#  (111, 'DT', 'the', 'the'),
#  (112, 'NN', 'monarch', 'monarch'),
#  (113, 'VBD', 'cited', 'cite'),
#  (114, 'NN', 'health', 'health'),
#  (115, 'NNS', 'reasons', 'reason'),
#  (116, 'IN', 'for', 'for'),
#  (117, 'VBG', 'stepping', 'step'),
#  (118, 'RP', 'down', 'down'),
#  (118, '.', '.', '.'),
#  (118, '``', '``', '``'),
#  (118, 'PRP', 'I', 'I'),
#  (119, 'VBP', 'am', 'be'),
#  (120, 'JJ', 'worried', 'worried'),
#  (121, 'IN', 'that', 'that'),
#  (122, 'PRP', 'it', 'it'),
#  (123, 'MD', 'may', 'may'),
#  (124, 'VB', 'become', 'become'),
#  (125, 'JJ', 'difficult', 'difficult'),
#  (126, 'IN', 'for', 'for'),
#  (127, 'PRP', 'me', 'me'),
#  (128, 'TO', 'to', 'to'),
#  (129, 'VB', 'carry', 'carry'),
#  (130, 'RP', 'out', 'out'),
#  (131, 'PRP$', 'my', 'my'),
#  (132, 'NNS', 'duties', 'duty'),
#  (133, 'IN', 'as', 'as'),
#  (134, 'DT', 'the', 'the'),
#  (135, 'NN', 'symbol', 'symbol'),
#  (136, 'IN', 'of', 'of'),
#  (137, 'DT', 'the', 'the'),
#  (138, 'NN', 'state', 'state'),
#  (139, 'IN', 'with', 'with'),
#  (140, 'PRP$', 'my', 'my'),
#  (141, 'JJ', 'whole', 'whole'),
#  (142, 'VBG', 'being', 'be'),
#  (142, ',', ',', ','),
#  (143, 'IN', 'as', 'as'),
#  (144, 'PRP', 'I', 'I'),
#  (145, 'VBP', 'have', 'have'),
#  (146, 'VBN', 'done', 'do'),
#  (147, 'IN', 'until', 'until'),
#  (148, 'RB', 'now', 'now'),
#  (148, ',', ',', ','),
#  (148, "''", "''", "''"),
#  (149, 'DT', 'the', 'the'),
#  (150, 'JJ', 'soft-spoken', 'soft-spoken'),
#  (151, 'NNP', 'Emperor', 'Emperor'),
#  (152, 'VBD', 'said', 'say'),
#  (153, 'IN', 'in', 'in'),
#  (154, 'CD', '2016', '2016'),
#  (154, ',', ',', ','),
#  (155, 'IN', 'in', 'in'),
#  (156, 'PRP$', 'his', 'his'),
#  (157, 'JJ', 'second', 'second'),
#  (158, 'NN', 'TV', 'TV'),
#  (159, 'NN', 'speech', 'speech'),
#  (160, 'IN', 'in', 'in'),
#  (161, 'CD', 'three', 'three'),
#  (162, 'NNS', 'decades', 'decade'),
#  (162, '.', '.', '.'),
#  (162, 'PRP', 'It', 'It'),
#  (163, 'VBD', 'was', 'be'),
#  (164, 'VBN', 'seen', 'see'),
#  (165, 'IN', 'as', 'as'),
#  (166, 'DT', 'a', 'a'),
#  (167, 'NN', 'plea', 'plea'),
#  (168, 'TO', 'to', 'to'),
#  (169, 'NNP', 'Japan', 'Japan'),
#  (169, 'POS', "'s", "'s"),
#  (170, 'NNS', 'lawmakers', 'lawmaker'),
#  (171, 'TO', 'to', 'to'),
#  (172, 'VB', 'change', 'change'),
#  (173, 'DT', 'the', 'the'),
#  (174, 'NN', 'law', 'law'),
#  (175, 'TO', 'to', 'to'),
#  (176, 'VB', 'allow', 'allow'),
#  (177, 'PRP', 'him', 'him'),
#  (178, 'TO', 'to', 'to'),
#  (179, 'VB', 'retire', 'retire'),
#  (179, '.', '.', '.'),
#  (180, 'DT', 'The', 'The'),
#  (181, 'JJ', 'following', 'following'),
#  (182, 'NN', 'year', 'year'),
#  (182, ',', ',', ','),
#  (183, 'PRP', 'they', 'they'),
#  (184, 'VBD', 'did', 'do'),
#  (184, '.', '.', '.'),
#  (184, '``', '``', '``'),
#  (184, 'PRP', 'It', 'It'),
#  (185, 'VBD', 'won', 'win'),
#  (186, 'NN', 'attention', 'attention'),
#  (187, 'CC', 'and', 'and'),
#  (188, 'NN', 'respect', 'respect'),
#  (189, 'IN', 'from', 'from'),
#  (190, 'DT', 'the', 'the'),
#  (191, 'NNS', 'people', 'people'),
#  (191, ',', ',', ','),
#  (192, 'WP', 'who', 'who'),
#  (193, 'VBD', 'recognized', 'recognize'),
#  (194, 'DT', 'the', 'the'),
#  (195, 'NN', 'emperor', 'emperor'),
#  (196, 'RB', 'actually', 'actually'),
#  (197, 'VBD', 'had', 'have'),
#  (198, 'DT', 'a', 'a'),
#  (199, 'MD', 'will', 'will'),
#  (200, 'IN', 'of', 'of'),
#  (201, 'PRP$', 'his', 'his'),
#  (202, 'JJ', 'own', 'own'),
#  (202, ',', ',', ','),
#  (202, "''", "''", "''"),
#  (203, 'VBD', 'said', 'say'),
#  (204, 'NNP', 'Hitomi', 'Hitomi'),
#  (205, 'NNP', 'Tonomura', 'Tonomura'),
#  (205, ',', ',', ','),
#  (206, 'DT', 'a', 'a'),
#  (207, 'NN', 'historian', 'historian'),
#  (208, 'IN', 'at', 'at'),
#  (209, 'NNP', 'University', 'University'),
#  (210, 'IN', 'of', 'of'),
#  (211, 'NNP', 'Michigan', 'Michigan'),
#  (211, 'POS', "'s", "'s"),
#  (212, 'NNP', 'Center', 'Center'),
#  (213, 'IN', 'for', 'for'),
#  (214, 'JJ', 'Japanese', 'Japanese'),
#  (215, 'NNPS', 'Studies', 'Studies'),
#  (215, '.', '.', '.'),
#  (215, 'PRP', 'It', 'It'),
#  (216, 'VBD', 'was', 'be'),
#  (217, 'DT', 'a', 'a'),
#  (218, 'JJ', 'fitting', 'fitting'),
#  (219, 'JJ', 'final', 'final'),
#  (220, 'NN', 'move', 'move'),
#  (221, 'IN', 'for', 'for'),
#  (222, 'DT', 'a', 'a'),
#  (223, 'NN', 'monarch', 'monarch'),
#  (224, 'WP', 'who', 'who'),
#  (225, 'VBD', 'had', 'have'),
#  (226, 'RB', 'often', 'often'),
#  (227, 'VBN', 'broken', 'break'),
#  (228, 'IN', 'with', 'with'),
#  (229, 'NN', 'tradition', 'tradition'),
#  (229, '.', '.', '.'),
#  (230, 'PRP', 'He', 'He'),
#  (231, 'VBD', 'was', 'be'),
#  (232, 'RB', 'also', 'also'),
#  (233, 'DT', 'the', 'the'),
#  (234, 'JJ', 'first', 'first'),
#  (235, 'JJ', 'Japanese', 'Japanese'),
#  (236, 'NN', 'Emperor', 'Emperor'),
#  (237, 'TO', 'to', 'to'),
#  (238, 'VB', 'marry', 'marry'),
#  (239, 'DT', 'a', 'a'),
#  (240, 'NN', 'commoner', 'commoner'),
#  (240, ',', ',', ','),
#  (241, 'NN', 'speak', 'speak'),
#  (242, 'TO', 'to', 'to'),
#  (243, 'PRP$', 'his', 'his'),
#  (244, 'NNS', 'subjects', 'subject'),
#  (245, 'VBP', 'live', 'live'),
#  (246, 'IN', 'on', 'on'),
#  (247, 'NN', 'television', 'television'),
#  (248, 'CC', 'and', 'and'),
#  (249, 'TO', 'to', 'to'),
#  (250, 'VB', 'be', 'be'),
#  (251, 'JJ', 'hands-on', 'hands-on'),
#  (252, 'IN', 'in', 'in'),
#  (253, 'VBG', 'raising', 'raise'),
#  (254, 'PRP$', 'his', 'his'),
#  (255, 'NNS', 'children', 'child'),
#  (255, '.', '.', '.')]

# %%
token_pos
# Out:
# [('Tokyo', 'NNP'),
#  ('(', '('),
#  ('CNN', 'NNP'),
#  (')', ')'),
#  ('Japan', 'NNP'),
#  ("'s", 'POS'),
#  ('85-year-old', 'JJ'),
#  ('monarch', 'NN'),
#  ('was', 'VBD'),
#  ('born', 'VBN'),
#  ('the', 'DT'),
#  ('son', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('deity', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('he', 'PRP'),
#  ("'s", 'VBZ'),
#  ('retiring', 'VBG'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('people', 'NNS'),
#  ("'s", 'POS'),
#  ('Emperor', 'NNP'),
#  ('.', '.'),
#  ('On', 'IN'),
#  ('Tuesday', 'NNP'),
#  (',', ','),
#  ('Emperor', 'NNP'),
#  ('Akihito', 'NNP'),
#  ('will', 'MD'),
#  ('abdicate', 'VB'),
#  ('the', 'DT'),
#  ('Chrysanthemum', 'NNP'),
#  ('Throne', 'NNP'),
#  ('--', ':'),
#  ('the', 'DT'),
#  ('oldest', 'JJS'),
#  ('continuous', 'JJ'),
#  ('hereditary', 'JJ'),
#  ('monarchy', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('--', ':'),
#  ('becoming', 'VBG'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('Japanese', 'JJ'),
#  ('monarch', 'NN'),
#  ('in', 'IN'),
#  ('modern', 'JJ'),
#  ('history', 'NN'),
#  ('to', 'TO'),
#  ('do', 'VB'),
#  ('so', 'RB'),
#  ('.', '.'),
#  ('His', 'PRP$'),
#  ('son', 'NN'),
#  (',', ','),
#  ('Crown', 'NNP'),
#  ('Prince', 'NNP'),
#  ('Naruhito', 'NNP'),
#  (',', ','),
#  ('59', 'CD'),
#  (',', ','),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('inaugurated', 'VBN'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('126th', 'CD'),
#  ('emperor', 'NN'),
#  ('the', 'DT'),
#  ('next', 'JJ'),
#  ('day', 'NN'),
#  (',', ','),
#  ('ushering', 'VBG'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Reiwa', 'NNP'),
#  ('era', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('much-loved', 'JJ'),
#  ('Emperor', 'NNP'),
#  ('Akihito', 'NNP'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('remembered', 'VBN'),
#  ('for', 'IN'),
#  ('connecting', 'VBG'),
#  ('with', 'IN'),
#  ('his', 'PRP$'),
#  ('public', 'NN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('way', 'NN'),
#  ('that', 'IN'),
#  ('no', 'DT'),
#  ('other', 'JJ'),
#  ('Japanese', 'JJ'),
#  ('monarch', 'NN'),
#  ('has', 'VBZ'),
#  ('done', 'VBN'),
#  ('and', 'CC'),
#  ('expressing', 'VBG'),
#  ('``', '``'),
#  ('deep', 'JJ'),
#  ('remorse', 'NN'),
#  ("''", "''"),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ("'s", 'POS'),
#  ('actions', 'NNS'),
#  ('during', 'IN'),
#  ('World', 'NNP'),
#  ('War', 'NNP'),
#  ('II', 'NNP'),
#  ('.', '.'),
#  ('After', 'IN'),
#  ('having', 'VBG'),
#  ('heart', 'NN'),
#  ('surgery', 'NN'),
#  ('and', 'CC'),
#  ('overcoming', 'VBG'),
#  ('prostate', 'NN'),
#  ('cancer', 'NN'),
#  ('in', 'IN'),
#  ('recent', 'JJ'),
#  ('years', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('monarch', 'NN'),
#  ('cited', 'VBD'),
#  ('health', 'NN'),
#  ('reasons', 'NNS'),
#  ('for', 'IN'),
#  ('stepping', 'VBG'),
#  ('down', 'RP'),
#  ('.', '.'),
#  ('``', '``'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('worried', 'JJ'),
#  ('that', 'IN'),
#  ('it', 'PRP'),
#  ('may', 'MD'),
#  ('become', 'VB'),
#  ('difficult', 'JJ'),
#  ('for', 'IN'),
#  ('me', 'PRP'),
#  ('to', 'TO'),
#  ('carry', 'VB'),
#  ('out', 'RP'),
#  ('my', 'PRP$'),
#  ('duties', 'NNS'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('symbol', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('state', 'NN'),
#  ('with', 'IN'),
#  ('my', 'PRP$'),
#  ('whole', 'JJ'),
#  ('being', 'VBG'),
#  (',', ','),
#  ('as', 'IN'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('done', 'VBN'),
#  ('until', 'IN'),
#  ('now', 'RB'),
#  (',', ','),
#  ("''", "''"),
#  ('the', 'DT'),
#  ('soft-spoken', 'JJ'),
#  ('Emperor', 'NNP'),
#  ('said', 'VBD'),
#  ('in', 'IN'),
#  ('2016', 'CD'),
#  (',', ','),
#  ('in', 'IN'),
#  ('his', 'PRP$'),
#  ('second', 'JJ'),
#  ('TV', 'NN'),
#  ('speech', 'NN'),
#  ('in', 'IN'),
#  ('three', 'CD'),
#  ('decades', 'NNS'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('was', 'VBD'),
#  ('seen', 'VBN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('plea', 'NN'),
#  ('to', 'TO'),
#  ('Japan', 'NNP'),
#  ("'s", 'POS'),
#  ('lawmakers', 'NNS'),
#  ('to', 'TO'),
#  ('change', 'VB'),
#  ('the', 'DT'),
#  ('law', 'NN'),
#  ('to', 'TO'),
#  ('allow', 'VB'),
#  ('him', 'PRP'),
#  ('to', 'TO'),
#  ('retire', 'VB'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('following', 'JJ'),
#  ('year', 'NN'),
#  (',', ','),
#  ('they', 'PRP'),
#  ('did', 'VBD'),
#  ('.', '.'),
#  ('``', '``'),
#  ('It', 'PRP'),
#  ('won', 'VBD'),
#  ('attention', 'NN'),
#  ('and', 'CC'),
#  ('respect', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('people', 'NNS'),
#  (',', ','),
#  ('who', 'WP'),
#  ('recognized', 'VBD'),
#  ('the', 'DT'),
#  ('emperor', 'NN'),
#  ('actually', 'RB'),
#  ('had', 'VBD'),
#  ('a', 'DT'),
#  ('will', 'MD'),
#  ('of', 'IN'),
#  ('his', 'PRP$'),
#  ('own', 'JJ'),
#  (',', ','),
#  ("''", "''"),
#  ('said', 'VBD'),
#  ('Hitomi', 'NNP'),
#  ('Tonomura', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('historian', 'NN'),
#  ('at', 'IN'),
#  ('University', 'NNP'),
#  ('of', 'IN'),
#  ('Michigan', 'NNP'),
#  ("'s", 'POS'),
#  ('Center', 'NNP'),
#  ('for', 'IN'),
#  ('Japanese', 'JJ'),
#  ('Studies', 'NNPS'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('fitting', 'JJ'),
#  ('final', 'JJ'),
#  ('move', 'NN'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('monarch', 'NN'),
#  ('who', 'WP'),
#  ('had', 'VBD'),
#  ('often', 'RB'),
#  ('broken', 'VBN'),
#  ('with', 'IN'),
#  ('tradition', 'NN'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('was', 'VBD'),
#  ('also', 'RB'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('Japanese', 'JJ'),
#  ('Emperor', 'NN'),
#  ('to', 'TO'),
#  ('marry', 'VB'),
#  ('a', 'DT'),
#  ('commoner', 'NN'),
#  (',', ','),
#  ('speak', 'NN'),
#  ('to', 'TO'),
#  ('his', 'PRP$'),
#  ('subjects', 'NNS'),
#  ('live', 'VBP'),
#  ('on', 'IN'),
#  ('television', 'NN'),
#  ('and', 'CC'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('hands-on', 'JJ'),
#  ('in', 'IN'),
#  ('raising', 'VBG'),
#  ('his', 'PRP$'),
#  ('children', 'NNS'),
#  ('.', '.')]

# %%
word_token
# Out:
# {0: ['Tokyo'],
#  1: ['(', 'CNN', ')', 'Japan', "'s"],
#  2: ['85-year-old'],
#  3: ['monarch'],
#  4: ['was'],
#  5: ['born'],
#  6: ['the'],
#  7: ['son'],
#  8: ['of'],
#  9: ['a'],
#  10: ['deity', ','],
#  11: ['but'],
#  12: ['he', "'s"],
#  13: ['retiring'],
#  14: ['as'],
#  15: ['the'],
#  16: ['people', "'s"],
#  17: ['Emperor', '.', 'On'],
#  18: ['Tuesday', ','],
#  19: ['Emperor'],
#  20: ['Akihito'],
#  21: ['will'],
#  22: ['abdicate'],
#  23: ['the'],
#  24: ['Chrysanthemum'],
#  25: ['Throne'],
#  26: ['--'],
#  27: ['the'],
#  28: ['oldest'],
#  29: ['continuous'],
#  30: ['hereditary'],
#  31: ['monarchy'],
#  32: ['in'],
#  33: ['the'],
#  34: ['world'],
#  35: ['--'],
#  36: ['becoming'],
#  37: ['the'],
#  38: ['first'],
#  39: ['Japanese'],
#  40: ['monarch'],
#  41: ['in'],
#  42: ['modern'],
#  43: ['history'],
#  44: ['to'],
#  45: ['do'],
#  46: ['so', '.'],
#  47: ['His'],
#  48: ['son', ','],
#  49: ['Crown'],
#  50: ['Prince'],
#  51: ['Naruhito', ','],
#  52: ['59', ','],
#  53: ['will'],
#  54: ['be'],
#  55: ['inaugurated'],
#  56: ['as'],
#  57: ['the'],
#  58: ['126th'],
#  59: ['emperor'],
#  60: ['the'],
#  61: ['next'],
#  62: ['day', ','],
#  63: ['ushering'],
#  64: ['in'],
#  65: ['the'],
#  66: ['Reiwa'],
#  67: ['era', '.', 'The'],
#  68: ['much-loved'],
#  69: ['Emperor'],
#  70: ['Akihito'],
#  71: ['will'],
#  72: ['be'],
#  73: ['remembered'],
#  74: ['for'],
#  75: ['connecting'],
#  76: ['with'],
#  77: ['his'],
#  78: ['public'],
#  79: ['in'],
#  80: ['a'],
#  81: ['way'],
#  82: ['that'],
#  83: ['no'],
#  84: ['other'],
#  85: ['Japanese'],
#  86: ['monarch'],
#  87: ['has'],
#  88: ['done'],
#  89: ['and'],
#  90: ['expressing'],
#  91: ['``', 'deep'],
#  92: ['remorse', "''"],
#  93: ['for'],
#  94: ['the'],
#  95: ['country', "'s"],
#  96: ['actions'],
#  97: ['during'],
#  98: ['World'],
#  99: ['War'],
#  100: ['II', '.', 'After'],
#  101: ['having'],
#  102: ['heart'],
#  103: ['surgery'],
#  104: ['and'],
#  105: ['overcoming'],
#  106: ['prostate'],
#  107: ['cancer'],
#  108: ['in'],
#  109: ['recent'],
#  110: ['years', ','],
#  111: ['the'],
#  112: ['monarch'],
#  113: ['cited'],
#  114: ['health'],
#  115: ['reasons'],
#  116: ['for'],
#  117: ['stepping'],
#  118: ['down', '.', '``', 'I'],
#  119: ['am'],
#  120: ['worried'],
#  121: ['that'],
#  122: ['it'],
#  123: ['may'],
#  124: ['become'],
#  125: ['difficult'],
#  126: ['for'],
#  127: ['me'],
#  128: ['to'],
#  129: ['carry'],
#  130: ['out'],
#  131: ['my'],
#  132: ['duties'],
#  133: ['as'],
#  134: ['the'],
#  135: ['symbol'],
#  136: ['of'],
#  137: ['the'],
#  138: ['state'],
#  139: ['with'],
#  140: ['my'],
#  141: ['whole'],
#  142: ['being', ','],
#  143: ['as'],
#  144: ['I'],
#  145: ['have'],
#  146: ['done'],
#  147: ['until'],
#  148: ['now', ',', "''"],
#  149: ['the'],
#  150: ['soft-spoken'],
#  151: ['Emperor'],
#  152: ['said'],
#  153: ['in'],
#  154: ['2016', ','],
#  155: ['in'],
#  156: ['his'],
#  157: ['second'],
#  158: ['TV'],
#  159: ['speech'],
#  160: ['in'],
#  161: ['three'],
#  162: ['decades', '.', 'It'],
#  163: ['was'],
#  164: ['seen'],
#  165: ['as'],
#  166: ['a'],
#  167: ['plea'],
#  168: ['to'],
#  169: ['Japan', "'s"],
#  170: ['lawmakers'],
#  171: ['to'],
#  172: ['change'],
#  173: ['the'],
#  174: ['law'],
#  175: ['to'],
#  176: ['allow'],
#  177: ['him'],
#  178: ['to'],
#  179: ['retire', '.'],
#  180: ['The'],
#  181: ['following'],
#  182: ['year', ','],
#  183: ['they'],
#  184: ['did', '.', '``', 'It'],
#  185: ['won'],
#  186: ['attention'],
#  187: ['and'],
#  188: ['respect'],
#  189: ['from'],
#  190: ['the'],
#  191: ['people', ','],
#  192: ['who'],
#  193: ['recognized'],
#  194: ['the'],
#  195: ['emperor'],
#  196: ['actually'],
#  197: ['had'],
#  198: ['a'],
#  199: ['will'],
#  200: ['of'],
#  201: ['his'],
#  202: ['own', ',', "''"],
#  203: ['said'],
#  204: ['Hitomi'],
#  205: ['Tonomura', ','],
#  206: ['a'],
#  207: ['historian'],
#  208: ['at'],
#  209: ['University'],
#  210: ['of'],
#  211: ['Michigan', "'s"],
#  212: ['Center'],
#  213: ['for'],
#  214: ['Japanese'],
#  215: ['Studies', '.', 'It'],
#  216: ['was'],
#  217: ['a'],
#  218: ['fitting'],
#  219: ['final'],
#  220: ['move'],
#  221: ['for'],
#  222: ['a'],
#  223: ['monarch'],
#  224: ['who'],
#  225: ['had'],
#  226: ['often'],
#  227: ['broken'],
#  228: ['with'],
#  229: ['tradition', '.'],
#  230: ['He'],
#  231: ['was'],
#  232: ['also'],
#  233: ['the'],
#  234: ['first'],
#  235: ['Japanese'],
#  236: ['Emperor'],
#  237: ['to'],
#  238: ['marry'],
#  239: ['a'],
#  240: ['commoner', ','],
#  241: ['speak'],
#  242: ['to'],
#  243: ['his'],
#  244: ['subjects'],
#  245: ['live'],
#  246: ['on'],
#  247: ['television'],
#  248: ['and'],
#  249: ['to'],
#  250: ['be'],
#  251: ['hands-on'],
#  252: ['in'],
#  253: ['raising'],
#  254: ['his'],
#  255: ['children', '.']}

# %%
paragraph
# Out:
# ['Tokyo',
#  "(CNN)Japan's",
#  '85-year-old',
#  'monarch',
#  'was',
#  'born',
#  'the',
#  'son',
#  'of',
#  'a',
#  'deity,',
#  'but',
#  "he's",
#  'retiring',
#  'as',
#  'the',
#  "people's",
#  'Emperor.\n\nOn',
#  'Tuesday,',
#  'Emperor',
#  'Akihito',
#  'will',
#  'abdicate',
#  'the',
#  'Chrysanthemum',
#  'Throne',
#  '--',
#  'the',
#  'oldest',
#  'continuous',
#  'hereditary',
#  'monarchy',
#  'in',
#  'the',
#  'world',
#  '--',
#  'becoming',
#  'the',
#  'first',
#  'Japanese',
#  'monarch',
#  'in',
#  'modern',
#  'history',
#  'to',
#  'do',
#  'so.',
#  'His',
#  'son,',
#  'Crown',
#  'Prince',
#  'Naruhito,',
#  '59,',
#  'will',
#  'be',
#  'inaugurated',
#  'as',
#  'the',
#  '126th',
#  'emperor',
#  'the',
#  'next',
#  'day,',
#  'ushering',
#  'in',
#  'the',
#  'Reiwa',
#  'era.\nThe',
#  'much-loved',
#  'Emperor',
#  'Akihito',
#  'will',
#  'be',
#  'remembered',
#  'for',
#  'connecting',
#  'with',
#  'his',
#  'public',
#  'in',
#  'a',
#  'way',
#  'that',
#  'no',
#  'other',
#  'Japanese',
#  'monarch',
#  'has',
#  'done',
#  'and',
#  'expressing',
#  '"deep',
#  'remorse"',
#  'for',
#  'the',
#  "country's",
#  'actions',
#  'during',
#  'World',
#  'War',
#  'II.\nAfter',
#  'having',
#  'heart',
#  'surgery',
#  'and',
#  'overcoming',
#  'prostate',
#  'cancer',
#  'in',
#  'recent',
#  'years,',
#  'the',
#  'monarch',
#  'cited',
#  'health',
#  'reasons',
#  'for',
#  'stepping',
#  'down.\n"I',
#  'am',
#  'worried',
#  'that',
#  'it',
#  'may',
#  'become',
#  'difficult',
#  'for',
#  'me',
#  'to',
#  'carry',
#  'out',
#  'my',
#  'duties',
#  'as',
#  'the',
#  'symbol',
#  'of',
#  'the',
#  'state',
#  'with',
#  'my',
#  'whole',
#  'being,',
#  'as',
#  'I',
#  'have',
#  'done',
#  'until',
#  'now,"',
#  'the',
#  'soft-spoken',
#  'Emperor',
#  'said',
#  'in',
#  '2016,',
#  'in',
#  'his',
#  'second',
#  'TV',
#  'speech',
#  'in',
#  'three',
#  'decades.\nIt',
#  'was',
#  'seen',
#  'as',
#  'a',
#  'plea',
#  'to',
#  "Japan's",
#  'lawmakers',
#  'to',
#  'change',
#  'the',
#  'law',
#  'to',
#  'allow',
#  'him',
#  'to',
#  'retire.',
#  'The',
#  'following',
#  'year,',
#  'they',
#  'did.\n"It',
#  'won',
#  'attention',
#  'and',
#  'respect',
#  'from',
#  'the',
#  'people,',
#  'who',
#  'recognized',
#  'the',
#  'emperor',
#  'actually',
#  'had',
#  'a',
#  'will',
#  'of',
#  'his',
#  'own,"',
#  'said',
#  'Hitomi',
#  'Tonomura,',
#  'a',
#  'historian',
#  'at',
#  'University',
#  'of',
#  "Michigan's",
#  'Center',
#  'for',
#  'Japanese',
#  'Studies.\nIt',
#  'was',
#  'a',
#  'fitting',
#  'final',
#  'move',
#  'for',
#  'a',
#  'monarch',
#  'who',
#  'had',
#  'often',
#  'broken',
#  'with',
#  'tradition.',
#  'He',
#  'was',
#  'also',
#  'the',
#  'first',
#  'Japanese',
#  'Emperor',
#  'to',
#  'marry',
#  'a',
#  'commoner,',
#  'speak',
#  'to',
#  'his',
#  'subjects',
#  'live',
#  'on',
#  'television',
#  'and',
#  'to',
#  'be',
#  'hands-on',
#  'in',
#  'raising',
#  'his',
#  'children.']

# %%
[row[0] for row in model.most_similar('wooing', topn=10) if row[1] > 0.5]
# Out:
# /anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# ['wooed', 'courting', 'luring', 'courted', 'woos', 'persuading']

# %%
model.most_similar('telescopes', topn=10)
# Out:
# /anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('telescope', 0.8120151162147522),
#  ('observatories', 0.6612797975540161),
#  ('astronomers', 0.621345043182373),
#  ('infrared', 0.6060433387756348),
#  ('ground-based', 0.5985158085823059),
#  ('microscopes', 0.573469877243042),
#  ('binoculars', 0.5701478719711304),
#  ('hubble', 0.5597853660583496),
#  ('observatory', 0.5295453071594238),
#  ('optical', 0.5255236625671387)]

# %%
synonymsPT('clasped')
# Out:
# gripped
# clutched
# embraced
# clamped
# squeezed
# tight
# cuddled
# grasped
# included
# enclosed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-7612c6171db1> in <module>()
# ----> 1 synonymsPT('clasped')
#
# <ipython-input-111-6e6ecde48d9b> in synonymsPT(word)
#      35     r = 'https://www.powerthesaurus.org/'+ word +'/synonyms'
#      36     synonymsList = crawl(r)
# ---> 37     for synonym in synonymsList:
#      38         count = sum([row[1] for row in ling[word[2]+" _"]][:10]) + sum([row[1] for row in ling["_ "+word[2]]][:10])
#      39         s_count = sum([row[1] for row in ling[synonym+" _"]][:10]) + sum([row[1] for row in ling["_ "+synonym]][:10])
#
# TypeError: 'NoneType' object is not iterable
